# %% [markdown]
# https://www.kaggle.com/ttahara/training-birdsong-baseline-resnest50-fast/data

# %% [markdown]
# # Birdsong Pytorch Baseline: ResNeSt50-fast (Training)

# %% [markdown]
# ## About
#
# In this notebook, I try ResNeSt, which is the one of state of the art in image recognition.
#
# For the fair comparison with @hidehisaarai1213 's [great baseline](https://www.kaggle.com/hidehisaarai1213/inference-pytorch-birdcall-resnet-baseline), I used a model with the same depth and as the same experimental settings as possible. But There are some differences mainly because of the GPU resource limitation.
#
# The experimental settings are as follows:
#
# * Randomly crop 5 seconds for each train audio clip each epoch.
# * No augmentation.
# * Used pretrained weight of _`ResNeSt50-fast-1s1x64d`_ provided by the authors at [their repository](https://github.com/zhanghang1989/ResNeSt).
# * Used `BCELoss`
# * Trained **_50_** epoch and saved the weight which got best **_loss_** (this is because f1 score relies on thresholds.)
# * `Adam` optimizer (`lr=0.001`) with `CosineAnnealingLR` (`T_max=10`).
# * Used `StratifiedKFold(n_splits=5)` to split dataset and used only first fold
# * `batch_size`: **_50_**
# * melspectrogram parameters
#   - `n_mels`: 128
#   - `fmin`: 20
#   - `fmax`: 16000
# * image size: 224x547
#
# I forked a lot of codes such as preprocessing from @hidehisaarai1213 's [notebook](https://www.kaggle.com/hidehisaarai1213/inference-pytorch-birdcall-resnet-baseline) and [GitHub repository](https://github.com/koukyo1994/kaggle-birdcall-resnet-baseline-training). Many thanks!!!
#
#
# ### Note
#
# #### about dataset
# I prepared resmpaled train dataset for this notebook, see more details in:
# https://www.kaggle.com/c/birdsong-recognition/discussion/164197
#
#
# #### about custom packages
# In this **_training notebook_**, I used two custom packages, `pytorch-pfn-extras` for training and the authors' official implementation of `ResNeSt` for building model.
# On the other hand, as stated in [code requirements](https://www.kaggle.com/c/birdsong-recognition/overview/code-requirements), participants are **not allowed** to use custom packages in **_submission notebook_**.
#
# If you fork this notebook, keep the above things in mind.
#
#
# ### Reference
#
# #### ResNeSt: Split-Attention Networks
# * author: Hang Zhang, Chongruo Wu, Zhongyue Zhang, Yi Zhu, Zhi Zhang, Haibin Lin, Yue Sun, Tong He, Jonas Muller, R. Manmatha, Mu Li and Alex Smola
# * paper: [arXiv 2004.08955](https://arxiv.org/abs/2004.08955)
# * code: [GitHub](https://github.com/koukyo1994/kaggle-birdcall-resnet-baseline-training)
#
# #### pytorch-pfn-extras
# * author: Preferred Networks, Inc.
# * code: [GitHub](https://github.com/pfnet/pytorch-pfn-extras)

# %% [markdown]
# ## Prepare

# %% [markdown]
# ### import libraries

# %%
# %%bash
# !pip install ../input/pytorch-pfn-extras/pytorch-pfn-extras-0.2.1/
# !pip install pytorch-pfn-extras
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pytorch-pfn-extras in /home/user/.local/lib/python3.6/site-packages (0.2.1)
# Requirement already satisfied: torch in /home/user/.local/lib/python3.6/site-packages (from pytorch-pfn-extras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from pytorch-pfn-extras) (1.17.4)
# WARNING: You are using pip version 20.1.1; however, version 20.2.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# %%bash
# pip install ../input/resnest50-fast-package/resnest-0.0.6b20200701/resnest/
# !pip install /home/knikaido/work/Cornell-Birdcall-Identification/data/resnest50-fast-package/resnest-0.0.6b20200701/resnest/
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Processing /home/knikaido/work/Cornell-Birdcall-Identification/data/resnest50-fast-package/resnest-0.0.6b20200701/resnest
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from resnest==0.0.6b20200821) (1.17.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from resnest==0.0.6b20200821) (4.46.1)
# Requirement already satisfied: nose in /home/user/.local/lib/python3.6/site-packages (from resnest==0.0.6b20200821) (1.3.7)
# Requirement already satisfied: torch>=1.0.0 in /home/user/.local/lib/python3.6/site-packages (from resnest==0.0.6b20200821) (1.4.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from resnest==0.0.6b20200821) (7.1.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from resnest==0.0.6b20200821) (1.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from resnest==0.0.6b20200821) (2.24.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->resnest==0.0.6b20200821) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->resnest==0.0.6b20200821) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->resnest==0.0.6b20200821) (2020.4.5.2)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->resnest==0.0.6b20200821) (2.9)
# Building wheels for collected packages: resnest
#   Building wheel for resnest (setup.py) ... done
#   Created wheel for resnest: filename=resnest-0.0.6b20200821-py3-none-any.whl size=30754 sha256=b55f0ee561073dca6e22f3e528e99b13641b74a646076554191d472422462d63
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vlzlapvc/wheels/98/b8/20/14b175a058326076510265be935570257f33b40bafba7255a9
# Successfully built resnest
# Installing collected packages: resnest
#   Attempting uninstall: resnest
#     Found existing installation: resnest 0.0.6b20200821
#     Uninstalling resnest-0.0.6b20200821:
#       Successfully uninstalled resnest-0.0.6b20200821
# Successfully installed resnest-0.0.6b20200821
# WARNING: You are using pip version 20.1.1; however, version 20.2.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# !pip install torch==1.4.0
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch==1.4.0 in /home/user/.local/lib/python3.6/site-packages (1.4.0)
# WARNING: You are using pip version 20.1.1; however, version 20.2.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in /home/user/.local/lib/python3.6/site-packages (4.4.0.42)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from opencv-python) (1.17.4)
# WARNING: You are using pip version 20.1.1; however, version 20.2.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import os
import gc
import time
import shutil
import random
import warnings
import typing as tp
from pathlib import Path
from contextlib import contextmanager

import yaml
from joblib import delayed, Parallel

import cv2
import librosa
import audioread
import soundfile as sf

import numpy as np
import pandas as pd

from sklearn.metrics import f1_score
from sklearn.model_selection import StratifiedKFold

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as data
import resnest.torch as resnest_torch

import pytorch_pfn_extras as ppe
from pytorch_pfn_extras.training import extensions as ppe_extensions

pd.options.display.max_rows = 500
pd.options.display.max_columns = 500

# %%
# Path("/root/.cache/torch/checkpoints").mkdir(parents=True)

# %%
# !cp ../input/resnest50-fast-package/resnest50_fast_*.pth /root/.cache/torch/checkpoints/

# %% [markdown]
# ### define utilities

# %%
def set_seed(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)  # type: ignore
#     torch.backends.cudnn.deterministic = True  # type: ignore
#     torch.backends.cudnn.benchmark = True  # type: ignore
    

@contextmanager
def timer(name: str) -> None:
    """Timer Util"""
    t0 = time.time()
    print("[{}] start".format(name))
    yield
    print("[{}] done in {:.0f} s".format(name, time.time() - t0))

# %% [markdown]
# ### read data

# %%
# ROOT = Path.cwd().parent
# INPUT_ROOT = ROOT / "input"
INPUT_ROOT = Path("/home/knikaido/work/Cornell-Birdcall-Identification/data")
RAW_DATA = INPUT_ROOT / "birdsong-recognition"
TRAIN_AUDIO_DIR = RAW_DATA / "train_audio"
TRAIN_RESAMPLED_AUDIO_DIRS = [
  INPUT_ROOT / "birdsong-resampled-train-audio-{:0>2}".format(i)  for i in range(5)
]
TEST_AUDIO_DIR = RAW_DATA / "test_audio"

# %%
# train = pd.read_csv(RAW_DATA / "train.csv")
train = pd.read_csv(TRAIN_RESAMPLED_AUDIO_DIRS[0] / "train_mod.csv")

# %%
train.head().T
# Out:
#                                                                          0  \
# rating                                                                 3.5
# playback_used                                                           no
# ebird_code                                                          aldfly
# channels                                                          1 (mono)
# date                                                            2013-05-25
# pitch                                                        Not specified
# duration                                                                25
# filename                                                      XC134874.mp3
# speed                                                        Not specified
# species                                                   Alder Flycatcher
# number_of_notes                                              Not specified
# title                        XC134874 Alder Flycatcher (Empidonax alnorum)
# secondary_labels         ['Empidonax minimus_Least Flycatcher', 'Leioth...
# bird_seen                                                              yes
# sci_name                                                 Empidonax alnorum
# location                       Grey Cloud Dunes SNA, Washington, Minnesota
# latitude                                                            44.793
# sampling_rate                                                   48000 (Hz)
# type                                                                  call
# elevation                                                            220 m
# description              Two short segments of fairly quiet *pip* calls...
# bitrate_of_mp3                                                192000 (bps)
# file_type                                                              mp3
# volume                                                       Not specified
# background               American Yellow Warbler (Setophaga aestiva); L...
# xc_id                                                               134874
# url                                      https://www.xeno-canto.org/134874
# country                                                      United States
# author                                                    Jonathon Jongsma
# primary_label                           Empidonax alnorum_Alder Flycatcher
# longitude                                                          -92.962
# length                                                       Not specified
# time                                                                  8:00
# recordist                                                 Jonathon Jongsma
# license                        Creative Commons Attribution-ShareAlike 3.0
# resampled_sampling_rate                                              32000
# resampled_filename                                            XC134874.wav
# resampled_channels                                                1 (mono)
#
#                                                                          1  \
# rating                                                                   4
# playback_used                                                           no
# ebird_code                                                          aldfly
# channels                                                        2 (stereo)
# date                                                            2013-05-27
# pitch                                                                 both
# duration                                                                36
# filename                                                      XC135454.mp3
# speed                                                                 both
# species                                                   Alder Flycatcher
# number_of_notes                                                        1-3
# title                        XC135454 Alder Flycatcher (Empidonax alnorum)
# secondary_labels                                                        []
# bird_seen                                                              yes
# sci_name                                                 Empidonax alnorum
# location                  Carver's Gap Parking area, Roan Mountain Stat...
# latitude                                                           36.1065
# sampling_rate                                                   44100 (Hz)
# type                                                            call, song
# elevation                                                           1700 m
# description              At least three birds seen here moving around s...
# bitrate_of_mp3                                                128000 (bps)
# file_type                                                              mp3
# volume                                                               level
# background                                                             NaN
# xc_id                                                               135454
# url                                      https://www.xeno-canto.org/135454
# country                                                      United States
# author                                                         Mike Nelson
# primary_label                           Empidonax alnorum_Alder Flycatcher
# longitude                                                         -82.1106
# length                                                              0-3(s)
# time                                                                 08:30
# recordist                                                      Mike Nelson
# license                  Creative Commons Attribution-NonCommercial-Sha...
# resampled_sampling_rate                                              32000
# resampled_filename                                            XC135454.wav
# resampled_channels                                                1 (mono)
#
#                                                                          2  \
# rating                                                                   4
# playback_used                                                           no
# ebird_code                                                          aldfly
# channels                                                        2 (stereo)
# date                                                            2013-05-27
# pitch                                                                 both
# duration                                                                39
# filename                                                      XC135455.mp3
# speed                                                                 both
# species                                                   Alder Flycatcher
# number_of_notes                                                        1-3
# title                        XC135455 Alder Flycatcher (Empidonax alnorum)
# secondary_labels                                                        []
# bird_seen                                                              yes
# sci_name                                                 Empidonax alnorum
# location                  Carver's Gap Parking area, Roan Mountain Stat...
# latitude                                                           36.1065
# sampling_rate                                                   44100 (Hz)
# type                                                            call, song
# elevation                                                           1700 m
# description              At least three birds seen chasing each other a...
# bitrate_of_mp3                                                128000 (bps)
# file_type                                                              mp3
# volume                                                               level
# background                                                             NaN
# xc_id                                                               135455
# url                                      https://www.xeno-canto.org/135455
# country                                                      United States
# author                                                         Mike Nelson
# primary_label                           Empidonax alnorum_Alder Flycatcher
# longitude                                                         -82.1106
# length                                                              0-3(s)
# time                                                                 08:30
# recordist                                                      Mike Nelson
# license                  Creative Commons Attribution-NonCommercial-Sha...
# resampled_sampling_rate                                              32000
# resampled_filename                                            XC135455.wav
# resampled_channels                                                1 (mono)
#
#                                                                          3  \
# rating                                                                 3.5
# playback_used                                                           no
# ebird_code                                                          aldfly
# channels                                                        2 (stereo)
# date                                                            2013-05-27
# pitch                                                                 both
# duration                                                                33
# filename                                                      XC135456.mp3
# speed                                                                 both
# species                                                   Alder Flycatcher
# number_of_notes                                                        1-3
# title                        XC135456 Alder Flycatcher (Empidonax alnorum)
# secondary_labels         ['Dumetella carolinensis_Gray Catbird', 'Bomby...
# bird_seen                                                              yes
# sci_name                                                 Empidonax alnorum
# location                  Carver's Gap Parking area, Roan Mountain Stat...
# latitude                                                           36.1065
# sampling_rate                                                   44100 (Hz)
# type                                                            call, song
# elevation                                                           1700 m
# description              img:http://www.flickr.com/photos/madbirder/888...
# bitrate_of_mp3                                                128000 (bps)
# file_type                                                              mp3
# volume                                                               level
# background               Grey Catbird (Dumetella carolinensis); Cedar W...
# xc_id                                                               135456
# url                                      https://www.xeno-canto.org/135456
# country                                                      United States
# author                                                         Mike Nelson
# primary_label                           Empidonax alnorum_Alder Flycatcher
# longitude                                                         -82.1106
# length                                                              0-3(s)
# time                                                                 08:30
# recordist                                                      Mike Nelson
# license                  Creative Commons Attribution-NonCommercial-Sha...
# resampled_sampling_rate                                              32000
# resampled_filename                                            XC135456.wav
# resampled_channels                                                1 (mono)
#
#                                                                          4
# rating                                                                   4
# playback_used                                                           no
# ebird_code                                                          aldfly
# channels                                                        2 (stereo)
# date                                                            2013-05-27
# pitch                                                                 both
# duration                                                                36
# filename                                                      XC135457.mp3
# speed                                                                level
# species                                                   Alder Flycatcher
# number_of_notes                                                        1-3
# title                        XC135457 Alder Flycatcher (Empidonax alnorum)
# secondary_labels                                                        []
# bird_seen                                                              yes
# sci_name                                                 Empidonax alnorum
# location                  Carver's Gap Parking area, Roan Mountain Stat...
# latitude                                                           36.1065
# sampling_rate                                                   44100 (Hz)
# type                                                            call, song
# elevation                                                           1700 m
# description              img:http://www.flickr.com/photos/madbirder/888...
# bitrate_of_mp3                                                128000 (bps)
# file_type                                                              mp3
# volume                                                               level
# background                                                             NaN
# xc_id                                                               135457
# url                                      https://www.xeno-canto.org/135457
# country                                                      United States
# author                                                         Mike Nelson
# primary_label                           Empidonax alnorum_Alder Flycatcher
# longitude                                                         -82.1106
# length                                                              0-3(s)
# time                                                                 08:30
# recordist                                                      Mike Nelson
# license                  Creative Commons Attribution-NonCommercial-Sha...
# resampled_sampling_rate                                              32000
# resampled_filename                                            XC135457.wav
# resampled_channels                                                1 (mono)

# %%
if not TEST_AUDIO_DIR.exists():
    TEST_AUDIO_DIR = INPUT_ROOT / "birdcall-check" / "test_audio"
    test = pd.read_csv(INPUT_ROOT / "birdcall-check" / "test.csv")
else:
    test = pd.read_csv(RAW_DATA / "test.csv")

# %%
test.head().T
# Out:
#                                                   0  \
# site                                         site_1
# row_id    site_1_41e6fe6504a34bf6846938ba78d13df1_5
# seconds                                           5
# audio_id           41e6fe6504a34bf6846938ba78d13df1
#
#                                                    1  \
# site                                          site_1
# row_id    site_1_41e6fe6504a34bf6846938ba78d13df1_10
# seconds                                           10
# audio_id            41e6fe6504a34bf6846938ba78d13df1
#
#                                                    2  \
# site                                          site_1
# row_id    site_1_41e6fe6504a34bf6846938ba78d13df1_15
# seconds                                           15
# audio_id            41e6fe6504a34bf6846938ba78d13df1
#
#                                                    3  \
# site                                          site_1
# row_id    site_1_41e6fe6504a34bf6846938ba78d13df1_20
# seconds                                           20
# audio_id            41e6fe6504a34bf6846938ba78d13df1
#
#                                                    4
# site                                          site_1
# row_id    site_1_41e6fe6504a34bf6846938ba78d13df1_25
# seconds                                           25
# audio_id            41e6fe6504a34bf6846938ba78d13df1

# %% [markdown]
# ### settings

# %%
settings_str = """
globals:
  seed: 1213
  device: cuda
  num_epochs: 50
  output_dir: ./training_output/
  use_fold: 0
  target_sr: 32000

dataset:
  name: SpectrogramDataset
  params:
    img_size: 224
    melspectrogram_parameters:
      n_mels: 128
      fmin: 20
      fmax: 16000
    
split:
  name: StratifiedKFold
  params:
    n_splits: 5
    random_state: 42
    shuffle: True

loader:
  train:
    batch_size: 16
    shuffle: True
    num_workers: 0
    pin_memory: True
    drop_last: True
  val:
    batch_size: 32
    shuffle: False
    num_workers: 0
    pin_memory: True
    drop_last: False

model:
  name: resnest50_fast_1s1x64d
  params:
    pretrained: True
    n_classes: 264

loss:
  name: BCEWithLogitsLoss
  params: {}

optimizer:
  name: Adam
  params:
    lr: 0.001

scheduler:
  name: CosineAnnealingLR
  params:
    T_max: 10
"""

# %%
settings = yaml.safe_load(settings_str)

# %%
# if not torch.cuda.is_available():
#     settings["globals"]["device"] = "cpu"

# %%
for k, v in settings.items():
    print("[{}]".format(k))
    print(v)
# Out:
# [globals]
# {'seed': 1213, 'device': 'cuda', 'num_epochs': 50, 'output_dir': './training_output/', 'use_fold': 0, 'target_sr': 32000}
# [dataset]
# {'name': 'SpectrogramDataset', 'params': {'img_size': 224, 'melspectrogram_parameters': {'n_mels': 128, 'fmin': 20, 'fmax': 16000}}}
# [split]
# {'name': 'StratifiedKFold', 'params': {'n_splits': 5, 'random_state': 42, 'shuffle': True}}
# [loader]
# {'train': {'batch_size': 16, 'shuffle': True, 'num_workers': 0, 'pin_memory': True, 'drop_last': True}, 'val': {'batch_size': 32, 'shuffle': False, 'num_workers': 0, 'pin_memory': True, 'drop_last': False}}
# [model]
# {'name': 'resnest50_fast_1s1x64d', 'params': {'pretrained': True, 'n_classes': 264}}
# [loss]
# {'name': 'BCEWithLogitsLoss', 'params': {}}
# [optimizer]
# {'name': 'Adam', 'params': {'lr': 0.001}}
# [scheduler]
# {'name': 'CosineAnnealingLR', 'params': {'T_max': 10}}

# %% [markdown]
# ### preprocess audio data
#
# Code is forked from: https://github.com/koukyo1994/kaggle-birdcall-resnet-baseline-training/blob/master/input/birdsong-recognition/prepare.py
#
# I modified this partially.
#
# However, in this notebook, I used uploaded resampled audio because this preprocessing is too heavy for kaggle notebook.

# %%
def resample(ebird_code: str,filename: str, target_sr: int):    
    audio_dir = TRAIN_AUDIO_DIR
    resample_dir = TRAIN_RESAMPLED_DIR
    ebird_dir = resample_dir / ebird_code
    
    try:
        y, _ = librosa.load(
            audio_dir / ebird_code / filename,
            sr=target_sr, mono=True, res_type="kaiser_fast")

        filename = filename.replace(".mp3", ".wav")
        sf.write(ebird_dir / filename, y, samplerate=target_sr)
    except Exception as e:
        print(e)
        with open("skipped.txt", "a") as f:
            file_path = str(audio_dir / ebird_code / filename)
            f.write(file_path + "\n")

# %%
# train_org = train.copy()
# TRAIN_RESAMPLED_DIR = Path("/kaggle/processed_data/train_audio_resampled")
# TRAIN_RESAMPLED_DIR.mkdir(parents=True)

# for ebird_code in train.ebird_code.unique():
#     ebird_dir = TRAIN_RESAMPLED_DIR / ebird_code
#     ebird_dir.mkdir()

# warnings.simplefilter("ignore")
# train_audio_infos = train[["ebird_code", "filename"]].values.tolist()
# Parallel(n_jobs=NUM_THREAD, verbose=10)(
#     delayed(resample)(ebird_code, file_name, TARGET_SR) for ebird_code, file_name in train_audio_infos)

# train["resampled_sampling_rate"] = TARGET_SR
# train["resampled_filename"] = train["filename"].map(
#     lambda x: x.replace(".mp3", ".wav"))
# train["resampled_channels"] = "1 (mono)"

# %% [markdown]
# ## Definition

# %% [markdown]
# ### Dataset
# * forked from: https://github.com/koukyo1994/kaggle-birdcall-resnet-baseline-training/blob/master/src/dataset.py
# * modified partialy

# %%
BIRD_CODE = {
    'aldfly': 0, 'ameavo': 1, 'amebit': 2, 'amecro': 3, 'amegfi': 4,
    'amekes': 5, 'amepip': 6, 'amered': 7, 'amerob': 8, 'amewig': 9,
    'amewoo': 10, 'amtspa': 11, 'annhum': 12, 'astfly': 13, 'baisan': 14,
    'baleag': 15, 'balori': 16, 'banswa': 17, 'barswa': 18, 'bawwar': 19,
    'belkin1': 20, 'belspa2': 21, 'bewwre': 22, 'bkbcuc': 23, 'bkbmag1': 24,
    'bkbwar': 25, 'bkcchi': 26, 'bkchum': 27, 'bkhgro': 28, 'bkpwar': 29,
    'bktspa': 30, 'blkpho': 31, 'blugrb1': 32, 'blujay': 33, 'bnhcow': 34,
    'boboli': 35, 'bongul': 36, 'brdowl': 37, 'brebla': 38, 'brespa': 39,
    'brncre': 40, 'brnthr': 41, 'brthum': 42, 'brwhaw': 43, 'btbwar': 44,
    'btnwar': 45, 'btywar': 46, 'buffle': 47, 'buggna': 48, 'buhvir': 49,
    'bulori': 50, 'bushti': 51, 'buwtea': 52, 'buwwar': 53, 'cacwre': 54,
    'calgul': 55, 'calqua': 56, 'camwar': 57, 'cangoo': 58, 'canwar': 59,
    'canwre': 60, 'carwre': 61, 'casfin': 62, 'caster1': 63, 'casvir': 64,
    'cedwax': 65, 'chispa': 66, 'chiswi': 67, 'chswar': 68, 'chukar': 69,
    'clanut': 70, 'cliswa': 71, 'comgol': 72, 'comgra': 73, 'comloo': 74,
    'commer': 75, 'comnig': 76, 'comrav': 77, 'comred': 78, 'comter': 79,
    'comyel': 80, 'coohaw': 81, 'coshum': 82, 'cowscj1': 83, 'daejun': 84,
    'doccor': 85, 'dowwoo': 86, 'dusfly': 87, 'eargre': 88, 'easblu': 89,
    'easkin': 90, 'easmea': 91, 'easpho': 92, 'eastow': 93, 'eawpew': 94,
    'eucdov': 95, 'eursta': 96, 'evegro': 97, 'fiespa': 98, 'fiscro': 99,
    'foxspa': 100, 'gadwal': 101, 'gcrfin': 102, 'gnttow': 103, 'gnwtea': 104,
    'gockin': 105, 'gocspa': 106, 'goleag': 107, 'grbher3': 108, 'grcfly': 109,
    'greegr': 110, 'greroa': 111, 'greyel': 112, 'grhowl': 113, 'grnher': 114,
    'grtgra': 115, 'grycat': 116, 'gryfly': 117, 'haiwoo': 118, 'hamfly': 119,
    'hergul': 120, 'herthr': 121, 'hoomer': 122, 'hoowar': 123, 'horgre': 124,
    'horlar': 125, 'houfin': 126, 'houspa': 127, 'houwre': 128, 'indbun': 129,
    'juntit1': 130, 'killde': 131, 'labwoo': 132, 'larspa': 133, 'lazbun': 134,
    'leabit': 135, 'leafly': 136, 'leasan': 137, 'lecthr': 138, 'lesgol': 139,
    'lesnig': 140, 'lesyel': 141, 'lewwoo': 142, 'linspa': 143, 'lobcur': 144,
    'lobdow': 145, 'logshr': 146, 'lotduc': 147, 'louwat': 148, 'macwar': 149,
    'magwar': 150, 'mallar3': 151, 'marwre': 152, 'merlin': 153, 'moublu': 154,
    'mouchi': 155, 'moudov': 156, 'norcar': 157, 'norfli': 158, 'norhar2': 159,
    'normoc': 160, 'norpar': 161, 'norpin': 162, 'norsho': 163, 'norwat': 164,
    'nrwswa': 165, 'nutwoo': 166, 'olsfly': 167, 'orcwar': 168, 'osprey': 169,
    'ovenbi1': 170, 'palwar': 171, 'pasfly': 172, 'pecsan': 173, 'perfal': 174,
    'phaino': 175, 'pibgre': 176, 'pilwoo': 177, 'pingro': 178, 'pinjay': 179,
    'pinsis': 180, 'pinwar': 181, 'plsvir': 182, 'prawar': 183, 'purfin': 184,
    'pygnut': 185, 'rebmer': 186, 'rebnut': 187, 'rebsap': 188, 'rebwoo': 189,
    'redcro': 190, 'redhea': 191, 'reevir1': 192, 'renpha': 193, 'reshaw': 194,
    'rethaw': 195, 'rewbla': 196, 'ribgul': 197, 'rinduc': 198, 'robgro': 199,
    'rocpig': 200, 'rocwre': 201, 'rthhum': 202, 'ruckin': 203, 'rudduc': 204,
    'rufgro': 205, 'rufhum': 206, 'rusbla': 207, 'sagspa1': 208, 'sagthr': 209,
    'savspa': 210, 'saypho': 211, 'scatan': 212, 'scoori': 213, 'semplo': 214,
    'semsan': 215, 'sheowl': 216, 'shshaw': 217, 'snobun': 218, 'snogoo': 219,
    'solsan': 220, 'sonspa': 221, 'sora': 222, 'sposan': 223, 'spotow': 224,
    'stejay': 225, 'swahaw': 226, 'swaspa': 227, 'swathr': 228, 'treswa': 229,
    'truswa': 230, 'tuftit': 231, 'tunswa': 232, 'veery': 233, 'vesspa': 234,
    'vigswa': 235, 'warvir': 236, 'wesblu': 237, 'wesgre': 238, 'weskin': 239,
    'wesmea': 240, 'wessan': 241, 'westan': 242, 'wewpew': 243, 'whbnut': 244,
    'whcspa': 245, 'whfibi': 246, 'whtspa': 247, 'whtswi': 248, 'wilfly': 249,
    'wilsni1': 250, 'wiltur': 251, 'winwre3': 252, 'wlswar': 253, 'wooduc': 254,
    'wooscj2': 255, 'woothr': 256, 'y00475': 257, 'yebfly': 258, 'yebsap': 259,
    'yehbla': 260, 'yelwar': 261, 'yerwar': 262, 'yetvir': 263
}

INV_BIRD_CODE = {v: k for k, v in BIRD_CODE.items()}

# %%
PERIOD = 5

def mono_to_color(
    X: np.ndarray, mean=None, std=None,
    norm_max=None, norm_min=None, eps=1e-6
):
    # Stack X as [X,X,X]
    X = np.stack([X, X, X], axis=-1)

    # Standardize
    mean = mean or X.mean()
    X = X - mean
    std = std or X.std()
    Xstd = X / (std + eps)
    _min, _max = Xstd.min(), Xstd.max()
    norm_max = norm_max or _max
    norm_min = norm_min or _min
    if (_max - _min) > eps:
        # Normalize to [0, 255]
        V = Xstd
        V[V < norm_min] = norm_min
        V[V > norm_max] = norm_max
        V = 255 * (V - norm_min) / (norm_max - norm_min)
        V = V.astype(np.uint8)
    else:
        # Just zero
        V = np.zeros_like(Xstd, dtype=np.uint8)
    return V

class SpectrogramDataset(data.Dataset):
    def __init__(
        self,
        file_list: tp.List[tp.List[str]], img_size=224,
        waveform_transforms=None, spectrogram_transforms=None, melspectrogram_parameters={}
    ):
        self.file_list = file_list  # list of list: [file_path, ebird_code]
        self.img_size = img_size
        self.waveform_transforms = waveform_transforms
        self.spectrogram_transforms = spectrogram_transforms
        self.melspectrogram_parameters = melspectrogram_parameters

    def __len__(self):
        return len(self.file_list)

    def __getitem__(self, idx: int):
        wav_path, ebird_code = self.file_list[idx]

        y, sr = sf.read(wav_path)

        if self.waveform_transforms:
            y = self.waveform_transforms(y)
        else:
            len_y = len(y)
            effective_length = sr * PERIOD
            if len_y < effective_length:
                new_y = np.zeros(effective_length, dtype=y.dtype)
                start = np.random.randint(effective_length - len_y)
                new_y[start:start + len_y] = y
                y = new_y.astype(np.float32)
            elif len_y > effective_length:
                start = np.random.randint(len_y - effective_length)
                y = y[start:start + effective_length].astype(np.float32)
            else:
                y = y.astype(np.float32)

        melspec = librosa.feature.melspectrogram(y, sr=sr, **self.melspectrogram_parameters)
        melspec = librosa.power_to_db(melspec).astype(np.float32)

        if self.spectrogram_transforms:
            melspec = self.spectrogram_transforms(melspec)
        else:
            pass

        image = mono_to_color(melspec)
        height, width, _ = image.shape
        image = cv2.resize(image, (int(width * self.img_size / height), self.img_size))
        image = np.moveaxis(image, 2, 0)
        image = (image / 255.0).astype(np.float32)

#         labels = np.zeros(len(BIRD_CODE), dtype="i")
        labels = np.zeros(len(BIRD_CODE), dtype="f")
        labels[BIRD_CODE[ebird_code]] = 1

        return image, labels

# %% [markdown]
# ### Training Utility

# %%
def get_loaders_for_training(
    args_dataset: tp.Dict, args_loader: tp.Dict,
    train_file_list: tp.List[str], val_file_list: tp.List[str]
):
    # # make dataset
    train_dataset = SpectrogramDataset(train_file_list, **args_dataset)
    val_dataset = SpectrogramDataset(val_file_list, **args_dataset)
    # # make dataloader
    train_loader = data.DataLoader(train_dataset, **args_loader["train"])
    val_loader = data.DataLoader(val_dataset, **args_loader["val"])
    
    return train_loader, val_loader

# %%
def get_model(args: tp.Dict):
    model =getattr(resnest_torch, args["name"])(pretrained=args["params"]["pretrained"])
    del model.fc
    # # use the same head as the baseline notebook.
    model.fc = nn.Sequential(
        nn.Linear(2048, 1024), nn.ReLU(), nn.Dropout(p=0.2),
        nn.Linear(1024, 1024), nn.ReLU(), nn.Dropout(p=0.2),
        nn.Linear(1024, args["params"]["n_classes"]))
    
    return model

# %%
def train_loop(
    manager, args, model, device,
    train_loader, optimizer, scheduler, loss_func
):
    """Run minibatch training loop"""
    while not manager.stop_trigger:
        model.train()
        for batch_idx, (data, target) in enumerate(train_loader):
            with manager.run_iteration():
                data, target = data.to(device), target.to(device)
                optimizer.zero_grad()
                output = model(data)
                loss = loss_func(output, target)
                ppe.reporting.report({'train/loss': loss.item()})
                loss.backward()
                optimizer.step()
                scheduler.step()
                
    return model

def eval_for_batch(
    args, model, device,
    data, target, loss_func, eval_func_dict={}
):
    """
    Run evaliation for valid
    
    This function is applied to each batch of val loader.
    """
    model.eval()
    data, target = data.to(device), target.to(device)
    output = model(data)
    # Final result will be average of averages of the same size
    val_loss = loss_func(output, target).item()
    ppe.reporting.report({'val/loss': val_loss})
    
    for eval_name, eval_func in eval_func_dict.items():
        eval_value = eval_func(output, target).item()
        ppe.reporting.report({"val/{}".format(eval_aame): eval_value})

# %%
def set_extensions(
    manager, args, model, device, test_loader, optimizer,
    loss_func, eval_func_dict={}
):
    """set extensions for PPE"""
        
    my_extensions = [
        # # observe, report
        ppe_extensions.observe_lr(optimizer=optimizer),
        # ppe_extensions.ParameterStatistics(model, prefix='model'),
        # ppe_extensions.VariableStatisticsPlot(model),
        ppe_extensions.LogReport(),
        ppe_extensions.PlotReport(['train/loss', 'val/loss'], 'epoch', filename='loss.png'),
        ppe_extensions.PlotReport(['lr',], 'epoch', filename='lr.png'),
        ppe_extensions.PrintReport([
            'epoch', 'iteration', 'lr', 'train/loss', 'val/loss', "elapsed_time"]),
#         ppe_extensions.ProgressBar(update_interval=100),

        # # evaluation
        (
            ppe_extensions.Evaluator(
                test_loader, model,
                eval_func=lambda data, target:
                    eval_for_batch(args, model, device, data, target, loss_func, eval_func_dict),
                progress_bar=True),
            (1, "epoch"),
        ),
        # # save model snapshot.
        (
            ppe_extensions.snapshot(
                target=model, filename="snapshot_epoch_{.updater.epoch}.pth"),
            ppe.training.triggers.MinValueTrigger(key="val/loss", trigger=(1, 'epoch'))
        ),
    ]
           
    # # set extensions to manager
    for ext in my_extensions:
        if isinstance(ext, tuple):
            manager.extend(ext[0], trigger=ext[1])
        else:
            manager.extend(ext)
        
    return manager

# %% [markdown]
# ## Training

# %% [markdown]
# ### prepare data

# %% [markdown]
# #### get wav file path

# %%
tmp_list = []
for audio_d in TRAIN_RESAMPLED_AUDIO_DIRS:
    if not audio_d.exists():
        continue
    for ebird_d in audio_d.iterdir():
        if ebird_d.is_file():
            continue
        for wav_f in ebird_d.iterdir():
            tmp_list.append([ebird_d.name, wav_f.name, wav_f.as_posix()])
            
train_wav_path_exist = pd.DataFrame(
    tmp_list, columns=["ebird_code", "resampled_filename", "file_path"])

del tmp_list

train_all = pd.merge(
    train, train_wav_path_exist, on=["ebird_code", "resampled_filename"], how="inner")

print(train.shape)
print(train_wav_path_exist.shape)
print(train_all.shape)
# Out:
# (21375, 38)
# (21375, 3)
# (21375, 39)

# %%
train_all.head()
# Out:
#    rating playback_used ebird_code    channels        date          pitch  \
# 0     3.5            no     aldfly    1 (mono)  2013-05-25  Not specified
# 1     4.0            no     aldfly  2 (stereo)  2013-05-27           both
# 2     4.0            no     aldfly  2 (stereo)  2013-05-27           both
# 3     3.5            no     aldfly  2 (stereo)  2013-05-27           both
# 4     4.0            no     aldfly  2 (stereo)  2013-05-27           both
#
#    duration      filename          speed           species number_of_notes  \
# 0        25  XC134874.mp3  Not specified  Alder Flycatcher   Not specified
# 1        36  XC135454.mp3           both  Alder Flycatcher             1-3
# 2        39  XC135455.mp3           both  Alder Flycatcher             1-3
# 3        33  XC135456.mp3           both  Alder Flycatcher             1-3
# 4        36  XC135457.mp3          level  Alder Flycatcher             1-3
#
#                                            title  \
# 0  XC134874 Alder Flycatcher (Empidonax alnorum)
# 1  XC135454 Alder Flycatcher (Empidonax alnorum)
# 2  XC135455 Alder Flycatcher (Empidonax alnorum)
# 3  XC135456 Alder Flycatcher (Empidonax alnorum)
# 4  XC135457 Alder Flycatcher (Empidonax alnorum)
#
#                                     secondary_labels bird_seen  \
# 0  ['Empidonax minimus_Least Flycatcher', 'Leioth...       yes
# 1                                                 []       yes
# 2                                                 []       yes
# 3  ['Dumetella carolinensis_Gray Catbird', 'Bomby...       yes
# 4                                                 []       yes
#
#             sci_name                                           location  \
# 0  Empidonax alnorum        Grey Cloud Dunes SNA, Washington, Minnesota
# 1  Empidonax alnorum   Carver's Gap Parking area, Roan Mountain Stat...
# 2  Empidonax alnorum   Carver's Gap Parking area, Roan Mountain Stat...
# 3  Empidonax alnorum   Carver's Gap Parking area, Roan Mountain Stat...
# 4  Empidonax alnorum   Carver's Gap Parking area, Roan Mountain Stat...
#
#   latitude sampling_rate        type elevation  \
# 0   44.793    48000 (Hz)        call     220 m
# 1  36.1065    44100 (Hz)  call, song    1700 m
# 2  36.1065    44100 (Hz)  call, song    1700 m
# 3  36.1065    44100 (Hz)  call, song    1700 m
# 4  36.1065    44100 (Hz)  call, song    1700 m
#
#                                          description bitrate_of_mp3 file_type  \
# 0  Two short segments of fairly quiet *pip* calls...   192000 (bps)       mp3
# 1  At least three birds seen here moving around s...   128000 (bps)       mp3
# 2  At least three birds seen chasing each other a...   128000 (bps)       mp3
# 3  img:http://www.flickr.com/photos/madbirder/888...   128000 (bps)       mp3
# 4  img:http://www.flickr.com/photos/madbirder/888...   128000 (bps)       mp3
#
#           volume                                         background   xc_id  \
# 0  Not specified  American Yellow Warbler (Setophaga aestiva); L...  134874
# 1          level                                                NaN  135454
# 2          level                                                NaN  135455
# 3          level  Grey Catbird (Dumetella carolinensis); Cedar W...  135456
# 4          level                                                NaN  135457
#
#                                  url        country            author  \
# 0  https://www.xeno-canto.org/134874  United States  Jonathon Jongsma
# 1  https://www.xeno-canto.org/135454  United States       Mike Nelson
# 2  https://www.xeno-canto.org/135455  United States       Mike Nelson
# 3  https://www.xeno-canto.org/135456  United States       Mike Nelson
# 4  https://www.xeno-canto.org/135457  United States       Mike Nelson
#
#                         primary_label longitude         length   time  \
# 0  Empidonax alnorum_Alder Flycatcher   -92.962  Not specified   8:00
# 1  Empidonax alnorum_Alder Flycatcher  -82.1106         0-3(s)  08:30
# 2  Empidonax alnorum_Alder Flycatcher  -82.1106         0-3(s)  08:30
# 3  Empidonax alnorum_Alder Flycatcher  -82.1106         0-3(s)  08:30
# 4  Empidonax alnorum_Alder Flycatcher  -82.1106         0-3(s)  08:30
#
#           recordist                                            license  \
# 0  Jonathon Jongsma        Creative Commons Attribution-ShareAlike 3.0
# 1       Mike Nelson  Creative Commons Attribution-NonCommercial-Sha...
# 2       Mike Nelson  Creative Commons Attribution-NonCommercial-Sha...
# 3       Mike Nelson  Creative Commons Attribution-NonCommercial-Sha...
# 4       Mike Nelson  Creative Commons Attribution-NonCommercial-Sha...
#
#    resampled_sampling_rate resampled_filename resampled_channels  \
# 0                    32000       XC134874.wav           1 (mono)
# 1                    32000       XC135454.wav           1 (mono)
# 2                    32000       XC135455.wav           1 (mono)
# 3                    32000       XC135456.wav           1 (mono)
# 4                    32000       XC135457.wav           1 (mono)
#
#                                            file_path
# 0  /home/knikaido/work/Cornell-Birdcall-Identific...
# 1  /home/knikaido/work/Cornell-Birdcall-Identific...
# 2  /home/knikaido/work/Cornell-Birdcall-Identific...
# 3  /home/knikaido/work/Cornell-Birdcall-Identific...
# 4  /home/knikaido/work/Cornell-Birdcall-Identific...

# %% [markdown]
# #### split data

# %%
# # for test run
# test_run_idx = sorted(np.random.choice(len(train_all), len(train_all) // 10, replace=False))
# train_all = train_all.iloc[test_run_idx, :].reset_index(drop=True)
# settings["globals"]["num_epochs"] = 20
# settings["scheduler"]["params"]["T_max"] = 4

# %%
skf = StratifiedKFold(**settings["split"]["params"])

train_all["fold"] = -1
for fold_id, (train_index, val_index) in enumerate(skf.split(train_all, train_all["ebird_code"])):
    train_all.iloc[val_index, -1] = fold_id
    
# # check the propotion
fold_proportion = pd.pivot_table(train_all, index="ebird_code", columns="fold", values="xc_id", aggfunc=len)
print(fold_proportion.shape)
# Out:
# (264, 5)

# %%
fold_proportion
# Out:
# fold         0   1   2   3   4
# ebird_code
# aldfly      20  20  20  20  20
# ameavo       8   8   8   7   7
# amebit       9   9   9   9   8
# amecro      20  20  20  20  20
# amegfi      20  20  20  20  20
# amekes      15  15  15  15  15
# amepip      20  20  20  20  20
# amered      20  20  20  20  20
# amerob      20  20  20  20  20
# amewig       7   7   7   6   6
# amewoo      17  17  17  16  16
# amtspa      15  15  15  15  14
# annhum      20  20  20  20  20
# astfly      20  20  20  20  20
# baisan      11  11  11  11  11
# baleag       7   7   7   7   7
# balori      20  20  20  20  20
# banswa      20  20  20  20  20
# barswa      20  20  20  20  20
# bawwar      15  15  15  15  14
# belkin1     14  14  14  14  13
# belspa2     16  15  15  15  15
# bewwre      20  20  20  20  20
# bkbcuc      10  10  10   9   9
# bkbmag1     12  12  12  12  12
# bkbwar      20  20  20  20  20
# bkcchi      20  20  20  20  20
# bkchum      14  14  14  13  13
# bkhgro      20  20  20  20  20
# bkpwar      20  20  20  20  20
# bktspa      19  19  19  19  18
# blkpho      20  20  20  20  20
# blugrb1     20  20  20  20  20
# blujay      20  20  20  20  20
# bnhcow      20  20  20  20  20
# boboli      20  20  20  20  20
# bongul       8   8   8   8   8
# brdowl      20  20  20  20  20
# brebla      10  10  10  10   9
# brespa      20  20  20  20  20
# brncre      20  20  20  20  20
# brnthr      20  20  20  20  20
# brthum      20  20  20  20  19
# brwhaw      15  15  15  15  14
# btbwar      15  15  15  15  15
# btnwar      20  20  20  20  20
# btywar      20  19  19  19  19
# buffle       3   3   3   3   3
# buggna      20  20  20  20  20
# buhvir      20  20  20  20  20
# bulori      20  20  20  20  20
# bushti      20  20  20  20  20
# buwtea      11  11  11  10  10
# buwwar      20  20  19  19  19
# cacwre      20  20  20  20  20
# calgul       8   8   8   8   8
# calqua      18  18  18  18  18
# camwar      16  15  15  15  15
# cangoo      20  20  20  20  20
# canwar      20  20  20  20  20
# canwre      20  20  20  20  20
# carwre      20  20  20  20  20
# casfin      16  15  15  15  15
# caster1     20  20  20  20  20
# casvir      18  18  18  18  18
# cedwax      18  18  18  18  17
# chispa      20  20  20  20  20
# chiswi       6   6   6   6   5
# chswar      20  20  20  20  20
# chukar       6   6   6   6   6
# clanut      16  16  16  16  15
# cliswa      13  13  13  13  13
# comgol      18  18  17  17  17
# comgra      20  20  20  20  20
# comloo      14  13  13  13  13
# commer      17  17  16  16  16
# comnig      18  17  17  17  17
# comrav      20  20  20  20  20
# comred      20  20  20  20  20
# comter      20  20  20  20  20
# comyel      20  20  20  20  20
# coohaw      18  18  18  18  18
# coshum       4   4   4   4   3
# cowscj1     14  14  14  14  13
# daejun      20  20  20  20  20
# doccor       7   7   7   7   6
# dowwoo      20  20  20  20  20
# dusfly      20  20  20  19  19
# eargre       8   8   7   7   7
# easblu      20  19  19  19  19
# easkin      17  17  16  16  16
# easmea      20  20  20  20  20
# easpho      19  18  18  18  18
# eastow      20  20  20  20  20
# eawpew      20  20  20  20  20
# eucdov      20  20  20  20  20
# eursta       8   8   8   8   8
# evegro      20  20  20  20  20
# fiespa      20  20  20  20  20
# fiscro      18  18  17  17  17
# foxspa      20  20  20  20  20
# gadwal      20  20  20  20  20
# gcrfin       7   6   6   6   6
# gnttow      20  20  20  20  20
# gnwtea      20  20  20  20  20
# gockin      20  20  20  20  20
# gocspa      14  14  14  14  14
# goleag      10  10  10  10  10
# grbher3     15  15  14  14  14
# grcfly      20  20  20  20  20
# greegr      20  20  20  20  20
# greroa      18  18  18  18  18
# greyel      20  20  20  20  20
# grhowl      20  20  20  20  20
# grnher      14  13  13  13  13
# grtgra      20  20  20  20  20
# grycat      17  17  16  16  16
# gryfly      17  16  16  16  16
# haiwoo      20  20  20  20  20
# hamfly      20  20  20  20  20
# hergul      20  20  20  20  20
# herthr      20  20  20  20  20
# hoomer       4   4   4   4   3
# hoowar      20  20  20  20  20
# horgre      14  14  13  13  13
# horlar      20  20  20  20  20
# houfin      20  20  20  20  20
# houspa      20  20  20  20  20
# houwre      20  20  20  20  20
# indbun      20  20  20  20  20
# juntit1     14  14  14  14  13
# killde      20  20  20  20  20
# labwoo      17  17  17  17  17
# larspa      19  19  19  19  19
# lazbun      20  20  19  19  19
# leabit      19  18  18  18  18
# leafly      19  19  19  19  19
# leasan      15  15  15  15  14
# lecthr       4   4   4   4   4
# lesgol      20  20  20  20  20
# lesnig       9   9   8   8   8
# lesyel      20  20  20  20  20
# lewwoo       6   6   6   5   5
# linspa      20  20  20  20  20
# lobcur      14  13  13  13  13
# lobdow      15  15  15  15  15
# logshr      20  20  20  20  20
# lotduc      12  12  12  12  12
# louwat      20  20  20  20  20
# macwar      20  20  20  20  20
# magwar      20  20  20  20  20
# mallar3     20  20  20  20  20
# marwre      20  20  20  20  20
# merlin      12  12  11  11  11
# moublu       6   6   6   6   6
# mouchi      20  20  20  20  20
# moudov      20  20  20  20  20
# norcar      20  20  20  20  20
# norfli      20  20  20  20  20
# norhar2      6   6   6   6   5
# normoc      20  20  20  20  20
# norpar      20  20  20  20  20
# norpin       8   8   8   8   7
# norsho      13  13  13  13  13
# norwat      20  20  20  20  20
# nrwswa       6   6   6   6   6
# nutwoo       9   9   9   9   8
# olsfly      20  20  20  20  20
# orcwar      20  20  20  20  20
# osprey      20  20  20  20  20
# ovenbi1     20  20  20  20  20
# palwar      10   9   9   9   9
# pasfly      20  20  20  20  20
# pecsan      14  13  13  13  13
# perfal      20  20  20  20  20
# phaino      12  12  12  12  12
# pibgre      20  20  20  20  20
# pilwoo      20  20  20  20  20
# pingro      19  19  19  18  18
# pinjay      11  10  10  10  10
# pinsis      20  20  20  20  20
# pinwar      20  20  20  20  20
# plsvir      19  19  18  18  18
# prawar      14  14  14  14  14
# purfin      20  20  20  20  20
# pygnut      12  12  12  12  12
# rebmer       6   6   6   6   5
# rebnut      20  20  20  20  20
# rebsap       7   7   6   6   6
# rebwoo      20  20  20  20  20
# redcro      20  20  20  20  20
# redhea       2   2   2   2   1
# reevir1     20  20  20  20  20
# renpha      15  15  15  15  14
# reshaw      15  15  15  14  14
# rethaw      19  19  19  18  18
# rewbla      20  20  20  20  20
# ribgul      14  13  13  13  13
# rinduc       5   5   5   5   5
# robgro      20  20  20  20  20
# rocpig      20  20  20  20  20
# rocwre      16  16  16  15  15
# rthhum       7   6   6   6   6
# ruckin      20  20  20  20  20
# rudduc       5   5   5   4   4
# rufgro       5   5   5   5   4
# rufhum      12  12  12  12  11
# rusbla      12  12  11  11  11
# sagspa1      6   6   6   6   6
# sagthr       7   7   7   7   7
# savspa      20  20  20  20  20
# saypho      11  11  11  11  11
# scatan      19  19  19  19  18
# scoori      20  20  20  20  20
# semplo      13  13  13  13  12
# semsan      14  14  14  14  14
# sheowl      12  12  11  11  11
# shshaw       5   5   4   4   4
# snobun      20  20  20  20  20
# snogoo      16  16  15  15  15
# solsan      19  19  19  19  18
# sonspa      20  20  20  20  20
# sora        20  20  20  20  20
# sposan      19  19  19  18  18
# spotow      20  20  20  20  20
# stejay      20  20  20  20  20
# swahaw       6   5   5   5   5
# swaspa      20  20  20  20  20
# swathr      20  20  20  20  20
# treswa      17  17  17  17  17
# truswa       8   8   8   7   7
# tuftit      20  20  20  20  20
# tunswa      13  13  13  13  12
# veery       20  20  20  20  20
# vesspa      20  20  20  20  20
# vigswa      11  11  10  10  10
# warvir      20  20  20  20  20
# wesblu       7   7   7   7   7
# wesgre       8   8   8   7   7
# weskin      17  17  17  16  16
# wesmea      20  20  20  20  20
# wessan       6   6   6   6   6
# westan      20  20  20  20  20
# wewpew      20  20  20  20  20
# whbnut      20  20  20  20  20
# whcspa      20  20  20  20  20
# whfibi       7   7   7   6   6
# whtspa      20  20  20  20  20
# whtswi       8   7   7   7   7
# wilfly      20  20  20  20  20
# wilsni1     20  20  20  20  20
# wiltur      10   9   9   9   9
# winwre3     20  20  20  20  20
# wlswar      20  20  20  20  20
# wooduc       8   8   8   8   8
# wooscj2     18  18  18  18  17
# woothr      20  20  20  20  20
# y00475      20  20  20  20  20
# yebfly      20  20  20  20  20
# yebsap      13  13  13  12  12
# yehbla      12  12  11  11  11
# yelwar      18  18  18  18  17
# yerwar      20  20  20  20  20
# yetvir      20  20  20  19  19

# %%
use_fold = settings["globals"]["use_fold"]
train_file_list = train_all.query("fold != @use_fold")[["file_path", "ebird_code"]].values.tolist()
val_file_list = train_all.query("fold == @use_fold")[["file_path", "ebird_code"]].values.tolist()

print("[fold {}] train: {}, val: {}".format(use_fold, len(train_file_list), len(val_file_list)))
# Out:
# [fold 0] train: 17057, val: 4318

# %% [markdown]
# ## run training

# %%
set_seed(settings["globals"]["seed"])
device = torch.device(settings["globals"]["device"])
output_dir = Path(settings["globals"]["output_dir"])

# # # get loader
train_loader, val_loader = get_loaders_for_training(
    settings["dataset"]["params"], settings["loader"], train_file_list, val_file_list)

# # # get model
model = get_model(settings["model"])
model = model.to(device)

# # # get optimizer
optimizer = getattr(
    torch.optim, settings["optimizer"]["name"]
)(model.parameters(), **settings["optimizer"]["params"])

# # # get scheduler
scheduler = getattr(
    torch.optim.lr_scheduler, settings["scheduler"]["name"]
)(optimizer, **settings["scheduler"]["params"])

# # # get loss
loss_func = getattr(nn, settings["loss"]["name"])(**settings["loss"]["params"])

# # # create training manager
trigger = None

manager = ppe.training.ExtensionsManager(
    model, optimizer, settings["globals"]["num_epochs"],
    iters_per_epoch=len(train_loader),
    stop_trigger=trigger,
    out_dir=output_dir
)

# # # set manager extensions
manager = set_extensions(
    manager, settings, model, device,
    val_loader, optimizer, loss_func,
)
# Out:
# Downloading: "https://s3.us-west-1.wasabisys.com/resnest/torch/resnest50_fast_1s1x64d-d8fbf808.pth" to /home/user/.cache/torch/checkpoints/resnest50_fast_1s1x64d-d8fbf808.pth
# HBox(children=(FloatProgress(value=0.0, max=105175365.0), HTML(value='')))

# %%
# # runtraining
model_res = train_loop(
    manager, settings, model, device,
    train_loader, optimizer, scheduler, loss_func)
# Out:
# epoch       iteration   lr          train/loss  val/loss    elapsed_time
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [..................................................]  0.74%
#          1 iterations
#    0.73945 iters/sec. Estimated time to finish: 0:03:01.216465.
# validation [..................................................]  1.48%
#          2 iterations
#     0.8866 iters/sec. Estimated time to finish: 0:02:30.010542.
# validation [#.................................................]  2.22%
#          3 iterations
#    0.84481 iters/sec. Estimated time to finish: 0:02:36.248820.
# validation [#.................................................]  2.96%
#          4 iterations
#    0.81119 iters/sec. Estimated time to finish: 0:02:41.491265.
# validation [#.................................................]  3.70%
#          5 iterations
#    0.77658 iters/sec. Estimated time to finish: 0:02:47.400899.
# validation [##................................................]  4.44%
#          6 iterations
#    0.74978 iters/sec. Estimated time to finish: 0:02:52.049553.
# validation [##................................................]  5.19%
#          7 iterations
#     0.7713 iters/sec. Estimated time to finish: 0:02:45.952972.
# validation [##................................................]  5.93%
#          8 iterations
#    0.77853 iters/sec. Estimated time to finish: 0:02:43.127958.
# validation [###...............................................]  6.67%
#          9 iterations
#    0.79668 iters/sec. Estimated time to finish: 0:02:38.156070.
# validation [###...............................................]  7.41%
#         10 iterations
#    0.81667 iters/sec. Estimated time to finish: 0:02:33.059933.
# validation [####..............................................]  8.15%
#         11 iterations
#    0.82587 iters/sec. Estimated time to finish: 0:02:30.145000.
# validation [####..............................................]  8.89%
#         12 iterations
#    0.84255 iters/sec. Estimated time to finish: 0:02:25.985254.
# validation [####..............................................]  9.63%
#         13 iterations
#    0.85653 iters/sec. Estimated time to finish: 0:02:22.434772.
# validation [#####.............................................] 10.37%
#         14 iterations
#    0.85183 iters/sec. Estimated time to finish: 0:02:22.046350.
# validation [#####.............................................] 11.11%
#         15 iterations
#    0.84952 iters/sec. Estimated time to finish: 0:02:21.256723.
# validation [#####.............................................] 11.85%
#         16 iterations
#    0.85728 iters/sec. Estimated time to finish: 0:02:18.811527.
# validation [######............................................] 12.59%
#         17 iterations
#    0.86955 iters/sec. Estimated time to finish: 0:02:15.701838.
# validation [######............................................] 13.33%
#         18 iterations
#    0.85583 iters/sec. Estimated time to finish: 0:02:16.709487.
# validation [#######...........................................] 14.07%
#         19 iterations
#    0.85469 iters/sec. Estimated time to finish: 0:02:15.721316.
# validation [#######...........................................] 14.81%
#         20 iterations
#    0.85361 iters/sec. Estimated time to finish: 0:02:14.721803.
# validation [#######...........................................] 15.56%
#         21 iterations
#    0.84118 iters/sec. Estimated time to finish: 0:02:15.524091.
# validation [########..........................................] 16.30%
#         22 iterations
#    0.84747 iters/sec. Estimated time to finish: 0:02:13.338785.
# validation [########..........................................] 17.04%
#         23 iterations
#    0.85312 iters/sec. Estimated time to finish: 0:02:11.282473.
# validation [########..........................................] 17.78%
#         24 iterations
#    0.85764 iters/sec. Estimated time to finish: 0:02:09.425496.
# validation [#########.........................................] 18.52%
#         25 iterations
#    0.85928 iters/sec. Estimated time to finish: 0:02:08.014584.
# validation [#########.........................................] 19.26%
#         26 iterations
#    0.84516 iters/sec. Estimated time to finish: 0:02:08.969158.
# validation [##########........................................] 20.00%
#         27 iterations
#    0.85324 iters/sec. Estimated time to finish: 0:02:06.576947.
# validation [##########........................................] 20.74%
#         28 iterations
#     0.8503 iters/sec. Estimated time to finish: 0:02:05.837775.
# validation [##########........................................] 21.48%
#         29 iterations
#    0.85068 iters/sec. Estimated time to finish: 0:02:04.605911.
# validation [###########.......................................] 22.22%
#         30 iterations
#    0.85207 iters/sec. Estimated time to finish: 0:02:03.228825.
# validation [###########.......................................] 22.96%
#         31 iterations
#    0.85549 iters/sec. Estimated time to finish: 0:02:01.567286.
# validation [###########.......................................] 23.70%
#         32 iterations
#    0.86112 iters/sec. Estimated time to finish: 0:01:59.611915.
# validation [############......................................] 24.44%
#         33 iterations
#    0.86753 iters/sec. Estimated time to finish: 0:01:57.575236.
# validation [############......................................] 25.19%
#         34 iterations
#    0.86506 iters/sec. Estimated time to finish: 0:01:56.755350.
# validation [############......................................] 25.93%
#         35 iterations
#    0.86284 iters/sec. Estimated time to finish: 0:01:55.896277.
# validation [#############.....................................] 26.67%
#         36 iterations
#    0.86304 iters/sec. Estimated time to finish: 0:01:54.711446.
# validation [#############.....................................] 27.41%
#         37 iterations
#    0.86756 iters/sec. Estimated time to finish: 0:01:52.959933.
# validation [##############....................................] 28.15%
#         38 iterations
#     0.8713 iters/sec. Estimated time to finish: 0:01:51.327921.
# validation [##############....................................] 28.89%
#         39 iterations
#    0.87416 iters/sec. Estimated time to finish: 0:01:49.820318.
# validation [##############....................................] 29.63%
#         40 iterations
#    0.87474 iters/sec. Estimated time to finish: 0:01:48.603378.
# validation [###############...................................] 30.37%
#         41 iterations
#     0.8781 iters/sec. Estimated time to finish: 0:01:47.049621.
# validation [###############...................................] 31.11%
#         42 iterations
#    0.87619 iters/sec. Estimated time to finish: 0:01:46.141937.
# validation [###############...................................] 31.85%
#         43 iterations
#    0.88096 iters/sec. Estimated time to finish: 0:01:44.432072.
# validation [################..................................] 32.59%
#         44 iterations
#    0.87999 iters/sec. Estimated time to finish: 0:01:43.410444.
# validation [################..................................] 33.33%
#         45 iterations
#    0.87932 iters/sec. Estimated time to finish: 0:01:42.351912.
# validation [#################.................................] 34.07%
#         46 iterations
#    0.88031 iters/sec. Estimated time to finish: 0:01:41.101083.
# validation [#################.................................] 34.81%
#         47 iterations
#      0.881 iters/sec. Estimated time to finish: 0:01:39.886334.
# validation [#################.................................] 35.56%
#         48 iterations
#    0.88168 iters/sec. Estimated time to finish: 0:01:38.674886.
# validation [##################................................] 36.30%
#         49 iterations
#    0.87905 iters/sec. Estimated time to finish: 0:01:37.832677.
# validation [##################................................] 37.04%
#         50 iterations
#    0.88121 iters/sec. Estimated time to finish: 0:01:36.458060.
# validation [##################................................] 37.78%
#         51 iterations
#    0.88039 iters/sec. Estimated time to finish: 0:01:35.412466.
# validation [###################...............................] 38.52%
#         52 iterations
#    0.87488 iters/sec. Estimated time to finish: 0:01:34.870061.
# validation [###################...............................] 39.26%
#         53 iterations
#    0.87767 iters/sec. Estimated time to finish: 0:01:33.428968.
# validation [####################..............................] 40.00%
#         54 iterations
#    0.87489 iters/sec. Estimated time to finish: 0:01:32.582757.
# validation [####################..............................] 40.74%
#         55 iterations
#    0.87557 iters/sec. Estimated time to finish: 0:01:31.369338.
# validation [####################..............................] 41.48%
#         56 iterations
#    0.87523 iters/sec. Estimated time to finish: 0:01:30.261640.
# validation [#####################.............................] 42.22%
#         57 iterations
#    0.87563 iters/sec. Estimated time to finish: 0:01:29.078272.
# validation [#####################.............................] 42.96%
#         58 iterations
#    0.87126 iters/sec. Estimated time to finish: 0:01:28.377529.
# validation [#####################.............................] 43.70%
#         59 iterations
#    0.87414 iters/sec. Estimated time to finish: 0:01:26.942286.
# validation [######################............................] 44.44%
#         60 iterations
#     0.8758 iters/sec. Estimated time to finish: 0:01:25.635975.
# validation [######################............................] 45.19%
#         61 iterations
#      0.875 iters/sec. Estimated time to finish: 0:01:24.571150.
# validation [######################............................] 45.93%
#         62 iterations
#    0.87255 iters/sec. Estimated time to finish: 0:01:23.663190.
# validation [#######################...........................] 46.67%
#         63 iterations
#    0.87026 iters/sec. Estimated time to finish: 0:01:22.733766.
# validation [#######################...........................] 47.41%
#         64 iterations
#    0.86905 iters/sec. Estimated time to finish: 0:01:21.698818.
# validation [########################..........................] 48.15%
#         65 iterations
#    0.86929 iters/sec. Estimated time to finish: 0:01:20.525914.
# validation [########################..........................] 48.89%
#         66 iterations
#    0.86846 iters/sec. Estimated time to finish: 0:01:19.451429.
# validation [########################..........................] 49.63%
#         67 iterations
#    0.86707 iters/sec. Estimated time to finish: 0:01:18.424912.
# validation [#########################.........................] 50.37%
#         68 iterations
#    0.86752 iters/sec. Estimated time to finish: 0:01:17.231847.
# validation [#########################.........................] 51.11%
#         69 iterations
#    0.87081 iters/sec. Estimated time to finish: 0:01:15.791691.
# validation [#########################.........................] 51.85%
#         70 iterations
#    0.87215 iters/sec. Estimated time to finish: 0:01:14.528114.
# validation [##########################........................] 52.59%
#         71 iterations
#    0.86968 iters/sec. Estimated time to finish: 0:01:13.589966.
# validation [##########################........................] 53.33%
#         72 iterations
#    0.87071 iters/sec. Estimated time to finish: 0:01:12.354586.
# validation [###########################.......................] 54.07%
#         73 iterations
#    0.87331 iters/sec. Estimated time to finish: 0:01:10.994094.
# validation [###########################.......................] 54.81%
#         74 iterations
#    0.87409 iters/sec. Estimated time to finish: 0:01:09.786518.
# validation [###########################.......................] 55.56%
#         75 iterations
#    0.87591 iters/sec. Estimated time to finish: 0:01:08.500427.
# validation [############################......................] 56.30%
#         76 iterations
#    0.87805 iters/sec. Estimated time to finish: 0:01:07.194410.
# validation [############################......................] 57.04%
#         77 iterations
#    0.87723 iters/sec. Estimated time to finish: 0:01:06.117560.
# validation [############################......................] 57.78%
#         78 iterations
#    0.87743 iters/sec. Estimated time to finish: 0:01:04.962175.
# validation [#############################.....................] 58.52%
#         79 iterations
#    0.87731 iters/sec. Estimated time to finish: 0:01:03.831819.
# validation [#############################.....................] 59.26%
#         80 iterations
#    0.87309 iters/sec. Estimated time to finish: 0:01:02.994959.
# validation [##############################....................] 60.00%
#         81 iterations
#    0.87328 iters/sec. Estimated time to finish: 0:01:01.835704.
# validation [##############################....................] 60.74%
#         82 iterations
#    0.87258 iters/sec. Estimated time to finish: 0:01:00.739362.
# validation [##############################....................] 61.48%
#         83 iterations
#    0.87429 iters/sec. Estimated time to finish: 0:00:59.477107.
# validation [###############################...................] 62.22%
#         84 iterations
#    0.87164 iters/sec. Estimated time to finish: 0:00:58.510217.
# validation [###############################...................] 62.96%
#         85 iterations
#    0.86921 iters/sec. Estimated time to finish: 0:00:57.523446.
# validation [###############################...................] 63.70%
#         86 iterations
#    0.87021 iters/sec. Estimated time to finish: 0:00:56.308199.
# validation [################################..................] 64.44%
#         87 iterations
#    0.86982 iters/sec. Estimated time to finish: 0:00:55.183788.
# validation [################################..................] 65.19%
#         88 iterations
#    0.86901 iters/sec. Estimated time to finish: 0:00:54.084436.
# validation [################################..................] 65.93%
#         89 iterations
#    0.86893 iters/sec. Estimated time to finish: 0:00:52.938383.
# validation [#################################.................] 66.67%
#         90 iterations
#    0.86818 iters/sec. Estimated time to finish: 0:00:51.832650.
# validation [#################################.................] 67.41%
#         91 iterations
#    0.87077 iters/sec. Estimated time to finish: 0:00:50.530028.
# validation [##################################................] 68.15%
#         92 iterations
#    0.87199 iters/sec. Estimated time to finish: 0:00:49.312506.
# validation [##################################................] 68.89%
#         93 iterations
#    0.87266 iters/sec. Estimated time to finish: 0:00:48.128535.
# validation [##################################................] 69.63%
#         94 iterations
#    0.87306 iters/sec. Estimated time to finish: 0:00:46.961201.
# validation [###################################...............] 70.37%
#         95 iterations
#    0.87354 iters/sec. Estimated time to finish: 0:00:45.790631.
# validation [###################################...............] 71.11%
#         96 iterations
#    0.86993 iters/sec. Estimated time to finish: 0:00:44.830949.
# validation [###################################...............] 71.85%
#         97 iterations
#    0.87007 iters/sec. Estimated time to finish: 0:00:43.674587.
# validation [####################################..............] 72.59%
#         98 iterations
#    0.87144 iters/sec. Estimated time to finish: 0:00:42.458566.
# validation [####################################..............] 73.33%
#         99 iterations
#     0.8707 iters/sec. Estimated time to finish: 0:00:41.345925.
# validation [#####################################.............] 74.07%
#        100 iterations
#    0.87316 iters/sec. Estimated time to finish: 0:00:40.084175.
# validation [#####################################.............] 74.81%
#        101 iterations
#    0.86976 iters/sec. Estimated time to finish: 0:00:39.091223.
# validation [#####################################.............] 75.56%
#        102 iterations
#    0.87184 iters/sec. Estimated time to finish: 0:00:37.851158.
# validation [######################################............] 76.30%
#        103 iterations
#    0.87511 iters/sec. Estimated time to finish: 0:00:36.566759.
# validation [######################################............] 77.04%
#        104 iterations
#    0.87873 iters/sec. Estimated time to finish: 0:00:35.278178.
# validation [######################################............] 77.78%
#        105 iterations
#    0.88183 iters/sec. Estimated time to finish: 0:00:34.020260.
# validation [#######################################...........] 78.52%
#        106 iterations
#    0.88141 iters/sec. Estimated time to finish: 0:00:32.901690.
# validation [#######################################...........] 79.26%
#        107 iterations
#    0.88051 iters/sec. Estimated time to finish: 0:00:31.799603.
# validation [########################################..........] 80.00%
#        108 iterations
#     0.8752 iters/sec. Estimated time to finish: 0:00:30.850132.
# validation [########################################..........] 80.74%
#        109 iterations
#    0.87173 iters/sec. Estimated time to finish: 0:00:29.825884.
# validation [########################################..........] 81.48%
#        110 iterations
#    0.87329 iters/sec. Estimated time to finish: 0:00:28.627517.
# validation [#########################################.........] 82.22%
#        111 iterations
#    0.87349 iters/sec. Estimated time to finish: 0:00:27.475998.
# validation [#########################################.........] 82.96%
#        112 iterations
#     0.8721 iters/sec. Estimated time to finish: 0:00:26.373132.
# validation [#########################################.........] 83.70%
#        113 iterations
#    0.87423 iters/sec. Estimated time to finish: 0:00:25.164918.
# validation [##########################################........] 84.44%
#        114 iterations
#    0.87501 iters/sec. Estimated time to finish: 0:00:23.999706.
# validation [##########################################........] 85.19%
#        115 iterations
#    0.87489 iters/sec. Estimated time to finish: 0:00:22.859976.
# validation [##########################################........] 85.93%
#        116 iterations
#    0.87296 iters/sec. Estimated time to finish: 0:00:21.765131.
# validation [###########################################.......] 86.67%
#        117 iterations
#     0.8737 iters/sec. Estimated time to finish: 0:00:20.602014.
# validation [###########################################.......] 87.41%
#        118 iterations
#    0.87327 iters/sec. Estimated time to finish: 0:00:19.467067.
# validation [############################################......] 88.15%
#        119 iterations
#     0.8734 iters/sec. Estimated time to finish: 0:00:18.319259.
# validation [############################################......] 88.89%
#        120 iterations
#    0.87384 iters/sec. Estimated time to finish: 0:00:17.165518.
# validation [############################################......] 89.63%
#        121 iterations
#    0.87133 iters/sec. Estimated time to finish: 0:00:16.067383.
# validation [#############################################.....] 90.37%
#        122 iterations
#    0.87012 iters/sec. Estimated time to finish: 0:00:14.940544.
# validation [#############################################.....] 91.11%
#        123 iterations
#    0.86828 iters/sec. Estimated time to finish: 0:00:13.820418.
# validation [#############################################.....] 91.85%
#        124 iterations
#     0.8692 iters/sec. Estimated time to finish: 0:00:12.655369.
# validation [##############################################....] 92.59%
#        125 iterations
#    0.87442 iters/sec. Estimated time to finish: 0:00:11.436206.
# validation [##############################################....] 93.33%
#        126 iterations
#      0.871 iters/sec. Estimated time to finish: 0:00:10.332989.
# validation [###############################################...] 94.07%
#        127 iterations
#    0.87287 iters/sec. Estimated time to finish: 0:00:09.165132.
# validation [###############################################...] 94.81%
#        128 iterations
#    0.87202 iters/sec. Estimated time to finish: 0:00:08.027380.
# validation [###############################################...] 95.56%
#        129 iterations
#    0.87296 iters/sec. Estimated time to finish: 0:00:06.873158.
# validation [################################################..] 96.30%
#        130 iterations
#    0.87365 iters/sec. Estimated time to finish: 0:00:05.723146.
# validation [################################################..] 97.04%
#        131 iterations
#    0.87439 iters/sec. Estimated time to finish: 0:00:04.574643.
# validation [################################################..] 97.78%
#        132 iterations
#    0.87088 iters/sec. Estimated time to finish: 0:00:03.444793.
# validation [#################################################.] 98.52%
#        133 iterations
#    0.87315 iters/sec. Estimated time to finish: 0:00:02.290554.
# validation [#################################################.] 99.26%
#        134 iterations
#    0.87438 iters/sec. Estimated time to finish: 0:00:01.143668.
# 1           1066        0.000345492  0.0275287   0.0247223   855.187
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [..................................................]  0.74%
#          1 iterations
#    0.65975 iters/sec. Estimated time to finish: 0:03:23.108734.
# validation [..................................................]  1.48%
#          2 iterations
#    0.82266 iters/sec. Estimated time to finish: 0:02:41.670600.
# validation [#.................................................]  2.22%
#          3 iterations
#    0.80241 iters/sec. Estimated time to finish: 0:02:44.503856.
# validation [#.................................................]  2.96%
#          4 iterations
#    0.77992 iters/sec. Estimated time to finish: 0:02:47.966347.
# validation [#.................................................]  3.70%
#          5 iterations
#    0.73838 iters/sec. Estimated time to finish: 0:02:56.060782.
# validation [##................................................]  4.44%
#          6 iterations
#    0.72737 iters/sec. Estimated time to finish: 0:02:57.352230.
# validation [##................................................]  5.19%
#          7 iterations
#    0.75554 iters/sec. Estimated time to finish: 0:02:49.414459.
# validation [##................................................]  5.93%
#          8 iterations
#    0.76172 iters/sec. Estimated time to finish: 0:02:46.728778.
# validation [###...............................................]  6.67%
#          9 iterations
#     0.7776 iters/sec. Estimated time to finish: 0:02:42.037510.
# validation [###...............................................]  7.41%
#         10 iterations
#    0.79493 iters/sec. Estimated time to finish: 0:02:37.247230.
# validation [####..............................................]  8.15%
#         11 iterations
#    0.79663 iters/sec. Estimated time to finish: 0:02:35.655507.
# validation [####..............................................]  8.89%
#         12 iterations
#    0.81166 iters/sec. Estimated time to finish: 0:02:31.541762.
# validation [####..............................................]  9.63%
#         13 iterations
#    0.82645 iters/sec. Estimated time to finish: 0:02:27.618897.
# validation [#####.............................................] 10.37%
#         14 iterations
#    0.82173 iters/sec. Estimated time to finish: 0:02:27.250129.
# validation [#####.............................................] 11.11%
#         15 iterations
#       0.82 iters/sec. Estimated time to finish: 0:02:26.341707.
# validation [#####.............................................] 11.85%
#         16 iterations
#    0.82881 iters/sec. Estimated time to finish: 0:02:23.579901.
# validation [######............................................] 12.59%
#         17 iterations
#    0.83709 iters/sec. Estimated time to finish: 0:02:20.964160.
# validation [######............................................] 13.33%
#         18 iterations
#    0.82845 iters/sec. Estimated time to finish: 0:02:21.226775.
# validation [#######...........................................] 14.07%
#         19 iterations
#    0.82775 iters/sec. Estimated time to finish: 0:02:20.138589.
# validation [#######...........................................] 14.81%
#         20 iterations
#     0.8258 iters/sec. Estimated time to finish: 0:02:19.258450.
# validation [#######...........................................] 15.56%
#         21 iterations
#    0.81752 iters/sec. Estimated time to finish: 0:02:19.446869.
# validation [########..........................................] 16.30%
#         22 iterations
#    0.82355 iters/sec. Estimated time to finish: 0:02:17.210512.
# validation [########..........................................] 17.04%
#         23 iterations
#    0.82773 iters/sec. Estimated time to finish: 0:02:15.309294.
# validation [########..........................................] 17.78%
#         24 iterations
#    0.83169 iters/sec. Estimated time to finish: 0:02:13.462424.
# validation [#########.........................................] 18.52%
#         25 iterations
#    0.83267 iters/sec. Estimated time to finish: 0:02:12.105865.
# validation [#########.........................................] 19.26%
#         26 iterations
#    0.81627 iters/sec. Estimated time to finish: 0:02:13.534544.
# validation [##########........................................] 20.00%
#         27 iterations
#    0.82467 iters/sec. Estimated time to finish: 0:02:10.961011.
# validation [##########........................................] 20.74%
#         28 iterations
#    0.82234 iters/sec. Estimated time to finish: 0:02:10.115925.
# validation [##########........................................] 21.48%
#         29 iterations
#    0.81959 iters/sec. Estimated time to finish: 0:02:09.333038.
# validation [###########.......................................] 22.22%
#         30 iterations
#    0.82201 iters/sec. Estimated time to finish: 0:02:07.736431.
# validation [###########.......................................] 22.96%
#         31 iterations
#    0.82642 iters/sec. Estimated time to finish: 0:02:05.843998.
# validation [###########.......................................] 23.70%
#         32 iterations
#    0.83317 iters/sec. Estimated time to finish: 0:02:03.624764.
# validation [############......................................] 24.44%
#         33 iterations
#    0.83951 iters/sec. Estimated time to finish: 0:02:01.499753.
# validation [############......................................] 25.19%
#         34 iterations
#    0.83668 iters/sec. Estimated time to finish: 0:02:00.715112.
# validation [############......................................] 25.93%
#         35 iterations
#    0.83457 iters/sec. Estimated time to finish: 0:01:59.822341.
# validation [#############.....................................] 26.67%
#         36 iterations
#     0.8374 iters/sec. Estimated time to finish: 0:01:58.222455.
# validation [#############.....................................] 27.41%
#         37 iterations
#    0.84049 iters/sec. Estimated time to finish: 0:01:56.598459.
# validation [##############....................................] 28.15%
#         38 iterations
#    0.84468 iters/sec. Estimated time to finish: 0:01:54.836599.
# validation [##############....................................] 28.89%
#         39 iterations
#    0.84986 iters/sec. Estimated time to finish: 0:01:52.959239.
# validation [##############....................................] 29.63%
#         40 iterations
#    0.85169 iters/sec. Estimated time to finish: 0:01:51.542854.
# validation [###############...................................] 30.37%
#         41 iterations
#    0.85604 iters/sec. Estimated time to finish: 0:01:49.807843.
# validation [###############...................................] 31.11%
#         42 iterations
#    0.85463 iters/sec. Estimated time to finish: 0:01:48.819055.
# validation [###############...................................] 31.85%
#         43 iterations
#    0.85997 iters/sec. Estimated time to finish: 0:01:46.980235.
# validation [################..................................] 32.59%
#         44 iterations
#     0.8596 iters/sec. Estimated time to finish: 0:01:45.862918.
# validation [################..................................] 33.33%
#         45 iterations
#    0.85734 iters/sec. Estimated time to finish: 0:01:44.975593.
# validation [#################.................................] 34.07%
#         46 iterations
#    0.85971 iters/sec. Estimated time to finish: 0:01:43.522744.
# validation [#################.................................] 34.81%
#         47 iterations
#    0.86121 iters/sec. Estimated time to finish: 0:01:42.181960.
# validation [#################.................................] 35.56%
#         48 iterations
#    0.86246 iters/sec. Estimated time to finish: 0:01:40.874103.
# validation [##################................................] 36.30%
#         49 iterations
#    0.86016 iters/sec. Estimated time to finish: 0:01:39.981865.
# validation [##################................................] 37.04%
#         50 iterations
#    0.86282 iters/sec. Estimated time to finish: 0:01:38.513762.
# validation [##################................................] 37.78%
#         51 iterations
#    0.86229 iters/sec. Estimated time to finish: 0:01:37.415552.
# validation [###################...............................] 38.52%
#         52 iterations
#    0.85783 iters/sec. Estimated time to finish: 0:01:36.756168.
# validation [###################...............................] 39.26%
#         53 iterations
#    0.86181 iters/sec. Estimated time to finish: 0:01:35.148878.
# validation [####################..............................] 40.00%
#         54 iterations
#    0.85964 iters/sec. Estimated time to finish: 0:01:34.225128.
# validation [####################..............................] 40.74%
#         55 iterations
#    0.86063 iters/sec. Estimated time to finish: 0:01:32.955205.
# validation [####################..............................] 41.48%
#         56 iterations
#    0.86108 iters/sec. Estimated time to finish: 0:01:31.744891.
# validation [#####################.............................] 42.22%
#         57 iterations
#    0.86201 iters/sec. Estimated time to finish: 0:01:30.486507.
# validation [#####################.............................] 42.96%
#         58 iterations
#    0.85958 iters/sec. Estimated time to finish: 0:01:29.578656.
# validation [#####################.............................] 43.70%
#         59 iterations
#    0.86294 iters/sec. Estimated time to finish: 0:01:28.071293.
# validation [######################............................] 44.44%
#         60 iterations
#    0.86507 iters/sec. Estimated time to finish: 0:01:26.698550.
# validation [######################............................] 45.19%
#         61 iterations
#    0.86563 iters/sec. Estimated time to finish: 0:01:25.486875.
# validation [######################............................] 45.93%
#         62 iterations
#    0.86366 iters/sec. Estimated time to finish: 0:01:24.524301.
# validation [#######################...........................] 46.67%
#         63 iterations
#    0.86282 iters/sec. Estimated time to finish: 0:01:23.447505.
# validation [#######################...........................] 47.41%
#         64 iterations
#    0.85965 iters/sec. Estimated time to finish: 0:01:22.591429.
# validation [########################..........................] 48.15%
#         65 iterations
#    0.86006 iters/sec. Estimated time to finish: 0:01:21.389332.
# validation [########################..........................] 48.89%
#         66 iterations
#    0.86075 iters/sec. Estimated time to finish: 0:01:20.162546.
# validation [########################..........................] 49.63%
#         67 iterations
#     0.8611 iters/sec. Estimated time to finish: 0:01:18.968919.
# validation [#########################.........................] 50.37%
#         68 iterations
#    0.85994 iters/sec. Estimated time to finish: 0:01:17.912808.
# validation [#########################.........................] 51.11%
#         69 iterations
#    0.86277 iters/sec. Estimated time to finish: 0:01:16.498022.
# validation [#########################.........................] 51.85%
#         70 iterations
#    0.86296 iters/sec. Estimated time to finish: 0:01:15.321909.
# validation [##########################........................] 52.59%
#         71 iterations
#    0.86116 iters/sec. Estimated time to finish: 0:01:14.317944.
# validation [##########################........................] 53.33%
#         72 iterations
#    0.86215 iters/sec. Estimated time to finish: 0:01:13.073071.
# validation [###########################.......................] 54.07%
#         73 iterations
#    0.86421 iters/sec. Estimated time to finish: 0:01:11.741810.
# validation [###########################.......................] 54.81%
#         74 iterations
#    0.86513 iters/sec. Estimated time to finish: 0:01:10.509341.
# validation [###########################.......................] 55.56%
#         75 iterations
#     0.8677 iters/sec. Estimated time to finish: 0:01:09.148137.
# validation [############################......................] 56.30%
#         76 iterations
#    0.86998 iters/sec. Estimated time to finish: 0:01:07.817307.
# validation [############################......................] 57.04%
#         77 iterations
#    0.86861 iters/sec. Estimated time to finish: 0:01:06.773539.
# validation [############################......................] 57.78%
#         78 iterations
#    0.87048 iters/sec. Estimated time to finish: 0:01:05.480803.
# validation [#############################.....................] 58.52%
#         79 iterations
#    0.87012 iters/sec. Estimated time to finish: 0:01:04.359196.
# validation [#############################.....................] 59.26%
#         80 iterations
#    0.86587 iters/sec. Estimated time to finish: 0:01:03.519573.
# validation [##############################....................] 60.00%
#         81 iterations
#     0.8655 iters/sec. Estimated time to finish: 0:01:02.391889.
# validation [##############################....................] 60.74%
#         82 iterations
#    0.86367 iters/sec. Estimated time to finish: 0:01:01.366118.
# validation [##############################....................] 61.48%
#         83 iterations
#    0.86425 iters/sec. Estimated time to finish: 0:01:00.167796.
# validation [###############################...................] 62.22%
#         84 iterations
#    0.86095 iters/sec. Estimated time to finish: 0:00:59.236631.
# validation [###############################...................] 62.96%
#         85 iterations
#    0.85818 iters/sec. Estimated time to finish: 0:00:58.262957.
# validation [###############################...................] 63.70%
#         86 iterations
#    0.85958 iters/sec. Estimated time to finish: 0:00:57.004871.
# validation [################################..................] 64.44%
#         87 iterations
#    0.86101 iters/sec. Estimated time to finish: 0:00:55.748661.
# validation [################################..................] 65.19%
#         88 iterations
#    0.85951 iters/sec. Estimated time to finish: 0:00:54.682026.
# validation [################################..................] 65.93%
#         89 iterations
#    0.85978 iters/sec. Estimated time to finish: 0:00:53.502340.
# validation [#################################.................] 66.67%
#         90 iterations
#    0.85962 iters/sec. Estimated time to finish: 0:00:52.348698.
# validation [#################################.................] 67.41%
#         91 iterations
#    0.86199 iters/sec. Estimated time to finish: 0:00:51.044632.
# validation [##################################................] 68.15%
#         92 iterations
#    0.86337 iters/sec. Estimated time to finish: 0:00:49.804787.
# validation [##################################................] 68.89%
#         93 iterations
#    0.86383 iters/sec. Estimated time to finish: 0:00:48.620807.
# validation [##################################................] 69.63%
#         94 iterations
#    0.86438 iters/sec. Estimated time to finish: 0:00:47.432662.
# validation [###################################...............] 70.37%
#         95 iterations
#    0.86363 iters/sec. Estimated time to finish: 0:00:46.316131.
# validation [###################################...............] 71.11%
#         96 iterations
#    0.85995 iters/sec. Estimated time to finish: 0:00:45.351649.
# validation [###################################...............] 71.85%
#         97 iterations
#    0.86022 iters/sec. Estimated time to finish: 0:00:44.174877.
# validation [####################################..............] 72.59%
#         98 iterations
#    0.85952 iters/sec. Estimated time to finish: 0:00:43.047415.
# validation [####################################..............] 73.33%
#         99 iterations
#    0.85789 iters/sec. Estimated time to finish: 0:00:41.963305.
# validation [#####################################.............] 74.07%
#        100 iterations
#       0.86 iters/sec. Estimated time to finish: 0:00:40.697482.
# validation [#####################################.............] 74.81%
#        101 iterations
#    0.85595 iters/sec. Estimated time to finish: 0:00:39.721943.
# validation [#####################################.............] 75.56%
#        102 iterations
#    0.85722 iters/sec. Estimated time to finish: 0:00:38.496731.
# validation [######################################............] 76.30%
#        103 iterations
#    0.85983 iters/sec. Estimated time to finish: 0:00:37.216684.
# validation [######################################............] 77.04%
#        104 iterations
#    0.86304 iters/sec. Estimated time to finish: 0:00:35.919451.
# validation [######################################............] 77.78%
#        105 iterations
#    0.86548 iters/sec. Estimated time to finish: 0:00:34.662959.
# validation [#######################################...........] 78.52%
#        106 iterations
#    0.86496 iters/sec. Estimated time to finish: 0:00:33.527419.
# validation [#######################################...........] 79.26%
#        107 iterations
#    0.86403 iters/sec. Estimated time to finish: 0:00:32.406203.
# validation [########################################..........] 80.00%
#        108 iterations
#     0.8588 iters/sec. Estimated time to finish: 0:00:31.439205.
# validation [########################################..........] 80.74%
#        109 iterations
#    0.85486 iters/sec. Estimated time to finish: 0:00:30.414224.
# validation [########################################..........] 81.48%
#        110 iterations
#     0.8564 iters/sec. Estimated time to finish: 0:00:29.191803.
# validation [#########################################.........] 82.22%
#        111 iterations
#    0.85594 iters/sec. Estimated time to finish: 0:00:28.039458.
# validation [#########################################.........] 82.96%
#        112 iterations
#    0.85454 iters/sec. Estimated time to finish: 0:00:26.914994.
# validation [#########################################.........] 83.70%
#        113 iterations
#    0.85649 iters/sec. Estimated time to finish: 0:00:25.686280.
# validation [##########################################........] 84.44%
#        114 iterations
#    0.85573 iters/sec. Estimated time to finish: 0:00:24.540403.
# validation [##########################################........] 85.19%
#        115 iterations
#    0.85463 iters/sec. Estimated time to finish: 0:00:23.401816.
# validation [##########################################........] 85.93%
#        116 iterations
#    0.85079 iters/sec. Estimated time to finish: 0:00:22.332127.
# validation [###########################################.......] 86.67%
#        117 iterations
#    0.85019 iters/sec. Estimated time to finish: 0:00:21.171753.
# validation [###########################################.......] 87.41%
#        118 iterations
#    0.84944 iters/sec. Estimated time to finish: 0:00:20.013289.
# validation [############################################......] 88.15%
#        119 iterations
#     0.8477 iters/sec. Estimated time to finish: 0:00:18.874502.
# validation [############################################......] 88.89%
#        120 iterations
#    0.84737 iters/sec. Estimated time to finish: 0:00:17.701853.
# validation [############################################......] 89.63%
#        121 iterations
#    0.84448 iters/sec. Estimated time to finish: 0:00:16.578242.
# validation [#############################################.....] 90.37%
#        122 iterations
#    0.84196 iters/sec. Estimated time to finish: 0:00:15.440232.
# validation [#############################################.....] 91.11%
#        123 iterations
#    0.83821 iters/sec. Estimated time to finish: 0:00:14.316262.
# validation [#############################################.....] 91.85%
#        124 iterations
#    0.83856 iters/sec. Estimated time to finish: 0:00:13.117785.
# validation [##############################################....] 92.59%
#        125 iterations
#    0.84385 iters/sec. Estimated time to finish: 0:00:11.850452.
# validation [##############################################....] 93.33%
#        126 iterations
#    0.83872 iters/sec. Estimated time to finish: 0:00:10.730663.
# validation [###############################################...] 94.07%
#        127 iterations
#    0.83902 iters/sec. Estimated time to finish: 0:00:09.534964.
# validation [###############################################...] 94.81%
#        128 iterations
#    0.83747 iters/sec. Estimated time to finish: 0:00:08.358526.
# validation [###############################################...] 95.56%
#        129 iterations
#      0.838 iters/sec. Estimated time to finish: 0:00:07.159931.
# validation [################################################..] 96.30%
#        130 iterations
#    0.83728 iters/sec. Estimated time to finish: 0:00:05.971691.
# validation [################################################..] 97.04%
#        131 iterations
#    0.83603 iters/sec. Estimated time to finish: 0:00:04.784531.
# validation [################################################..] 97.78%
#        132 iterations
#    0.83136 iters/sec. Estimated time to finish: 0:00:03.608560.
# validation [#################################################.] 98.52%
#        133 iterations
#    0.83238 iters/sec. Estimated time to finish: 0:00:02.402746.
# validation [#################################################.] 99.26%
#        134 iterations
#    0.83337 iters/sec. Estimated time to finish: 0:00:01.199941.
# 2           2132        9.54915e-05  0.0232634   0.0221058   1740.14
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [..................................................]  0.74%
#          1 iterations
#    0.64959 iters/sec. Estimated time to finish: 0:03:26.283575.
# validation [..................................................]  1.48%
#          2 iterations
#    0.78661 iters/sec. Estimated time to finish: 0:02:49.079058.
# validation [#.................................................]  2.22%
#          3 iterations
#    0.77429 iters/sec. Estimated time to finish: 0:02:50.478348.
# validation [#.................................................]  2.96%
#          4 iterations
#    0.75338 iters/sec. Estimated time to finish: 0:02:53.883376.
# validation [#.................................................]  3.70%
#          5 iterations
#    0.73148 iters/sec. Estimated time to finish: 0:02:57.721928.
# validation [##................................................]  4.44%
#          6 iterations
#    0.72397 iters/sec. Estimated time to finish: 0:02:58.185210.
# validation [##................................................]  5.19%
#          7 iterations
#    0.74518 iters/sec. Estimated time to finish: 0:02:51.769588.
# validation [##................................................]  5.93%
#          8 iterations
#    0.76056 iters/sec. Estimated time to finish: 0:02:46.982264.
# validation [###...............................................]  6.67%
#          9 iterations
#    0.77317 iters/sec. Estimated time to finish: 0:02:42.965432.
# validation [###...............................................]  7.41%
#         10 iterations
#    0.78625 iters/sec. Estimated time to finish: 0:02:38.982334.
# validation [####..............................................]  8.15%
#         11 iterations
#    0.79143 iters/sec. Estimated time to finish: 0:02:36.679042.
# validation [####..............................................]  8.89%
#         12 iterations
#    0.80516 iters/sec. Estimated time to finish: 0:02:32.764832.
# validation [####..............................................]  9.63%
#         13 iterations
#    0.81972 iters/sec. Estimated time to finish: 0:02:28.830613.
# validation [#####.............................................] 10.37%
#         14 iterations
#    0.81511 iters/sec. Estimated time to finish: 0:02:28.445386.
# validation [#####.............................................] 11.11%
#         15 iterations
#    0.80811 iters/sec. Estimated time to finish: 0:02:28.493952.
# validation [#####.............................................] 11.85%
#         16 iterations
#    0.81749 iters/sec. Estimated time to finish: 0:02:25.566812.
# validation [######............................................] 12.59%
#         17 iterations
#    0.82749 iters/sec. Estimated time to finish: 0:02:22.599055.
# validation [######............................................] 13.33%
#         18 iterations
#    0.81699 iters/sec. Estimated time to finish: 0:02:23.207968.
# validation [#######...........................................] 14.07%
#         19 iterations
#    0.81722 iters/sec. Estimated time to finish: 0:02:21.944077.
# validation [#######...........................................] 14.81%
#         20 iterations
#    0.81634 iters/sec. Estimated time to finish: 0:02:20.871894.
# validation [#######...........................................] 15.56%
#         21 iterations
#     0.8066 iters/sec. Estimated time to finish: 0:02:21.333852.
# validation [########..........................................] 16.30%
#         22 iterations
#    0.81177 iters/sec. Estimated time to finish: 0:02:19.201235.
# validation [########..........................................] 17.04%
#         23 iterations
#    0.81795 iters/sec. Estimated time to finish: 0:02:16.927139.
# validation [########..........................................] 17.78%
#         24 iterations
#    0.82101 iters/sec. Estimated time to finish: 0:02:15.199667.
# validation [#########.........................................] 18.52%
#         25 iterations
#    0.82235 iters/sec. Estimated time to finish: 0:02:13.763163.
# validation [#########.........................................] 19.26%
#         26 iterations
#    0.80631 iters/sec. Estimated time to finish: 0:02:15.182905.
# validation [##########........................................] 20.00%
#         27 iterations
#    0.81293 iters/sec. Estimated time to finish: 0:02:12.852050.
# validation [##########........................................] 20.74%
#         28 iterations
#    0.81073 iters/sec. Estimated time to finish: 0:02:11.980185.
# validation [##########........................................] 21.48%
#         29 iterations
#    0.80826 iters/sec. Estimated time to finish: 0:02:11.146385.
# validation [###########.......................................] 22.22%
#         30 iterations
#    0.80944 iters/sec. Estimated time to finish: 0:02:09.719698.
# validation [###########.......................................] 22.96%
#         31 iterations
#    0.81228 iters/sec. Estimated time to finish: 0:02:08.034972.
# validation [###########.......................................] 23.70%
#         32 iterations
#    0.81744 iters/sec. Estimated time to finish: 0:02:06.002716.
# validation [############......................................] 24.44%
#         33 iterations
#    0.82334 iters/sec. Estimated time to finish: 0:02:03.885092.
# ...
#    0.74967 iters/sec. Estimated time to finish: 0:02:16.060761.
# validation [############......................................] 25.19%
#         34 iterations
#    0.74975 iters/sec. Estimated time to finish: 0:02:14.710949.
# validation [############......................................] 25.93%
#         35 iterations
#    0.74854 iters/sec. Estimated time to finish: 0:02:13.594282.
# validation [#############.....................................] 26.67%
#         36 iterations
#    0.75127 iters/sec. Estimated time to finish: 0:02:11.777395.
# validation [#############.....................................] 27.41%
#         37 iterations
#    0.75508 iters/sec. Estimated time to finish: 0:02:09.787728.
# validation [##############....................................] 28.15%
#         38 iterations
#    0.75967 iters/sec. Estimated time to finish: 0:02:07.686845.
# validation [##############....................................] 28.89%
#         39 iterations
#    0.76203 iters/sec. Estimated time to finish: 0:02:05.979942.
# validation [##############....................................] 29.63%
#         40 iterations
#    0.76591 iters/sec. Estimated time to finish: 0:02:04.035325.
# validation [###############...................................] 30.37%
#         41 iterations
#    0.77061 iters/sec. Estimated time to finish: 0:02:01.981048.
# validation [###############...................................] 31.11%
#         42 iterations
#    0.77066 iters/sec. Estimated time to finish: 0:02:00.675840.
# validation [###############...................................] 31.85%
#         43 iterations
#    0.77504 iters/sec. Estimated time to finish: 0:01:58.704073.
# validation [################..................................] 32.59%
#         44 iterations
#    0.77655 iters/sec. Estimated time to finish: 0:01:57.184308.
# validation [################..................................] 33.33%
#         45 iterations
#    0.77687 iters/sec. Estimated time to finish: 0:01:55.850171.
# validation [#################.................................] 34.07%
#         46 iterations
#    0.78047 iters/sec. Estimated time to finish: 0:01:54.033385.
# validation [#################.................................] 34.81%
#         47 iterations
#    0.78094 iters/sec. Estimated time to finish: 0:01:52.684434.
# validation [#################.................................] 35.56%
#         48 iterations
#     0.7812 iters/sec. Estimated time to finish: 0:01:51.367466.
# validation [##################................................] 36.30%
#         49 iterations
#    0.77987 iters/sec. Estimated time to finish: 0:01:50.275322.
# validation [##################................................] 37.04%
#         50 iterations
#    0.78169 iters/sec. Estimated time to finish: 0:01:48.738936.
# validation [##################................................] 37.78%
#         51 iterations
#    0.78167 iters/sec. Estimated time to finish: 0:01:47.461866.
# validation [###################...............................] 38.52%
#         52 iterations
#    0.78149 iters/sec. Estimated time to finish: 0:01:46.207032.
# validation [###################...............................] 39.26%
#         53 iterations
#     0.7834 iters/sec. Estimated time to finish: 0:01:44.671346.
# validation [####################..............................] 40.00%
#         54 iterations
#    0.78246 iters/sec. Estimated time to finish: 0:01:43.519816.
# validation [####################..............................] 40.74%
#         55 iterations
#    0.78353 iters/sec. Estimated time to finish: 0:01:42.101684.
# validation [####################..............................] 41.48%
#         56 iterations
#    0.78166 iters/sec. Estimated time to finish: 0:01:41.067420.
# validation [#####################.............................] 42.22%
#         57 iterations
#    0.78338 iters/sec. Estimated time to finish: 0:01:39.568642.
# validation [#####################.............................] 42.96%
#         58 iterations
#    0.78294 iters/sec. Estimated time to finish: 0:01:38.347194.
# validation [#####################.............................] 43.70%
#         59 iterations
#    0.78491 iters/sec. Estimated time to finish: 0:01:36.826884.
# validation [######################............................] 44.44%
#         60 iterations
#      0.787 iters/sec. Estimated time to finish: 0:01:35.298412.
# validation [######################............................] 45.19%
#         61 iterations
#    0.78824 iters/sec. Estimated time to finish: 0:01:33.879582.
# validation [######################............................] 45.93%
#         62 iterations
#     0.7895 iters/sec. Estimated time to finish: 0:01:32.464033.
# validation [#######################...........................] 46.67%
#         63 iterations
#    0.78881 iters/sec. Estimated time to finish: 0:01:31.277261.
# validation [#######################...........................] 47.41%
#         64 iterations
#    0.78958 iters/sec. Estimated time to finish: 0:01:29.920977.
# validation [########################..........................] 48.15%
#         65 iterations
#    0.78988 iters/sec. Estimated time to finish: 0:01:28.621528.
# validation [########################..........................] 48.89%
#         66 iterations
#    0.78908 iters/sec. Estimated time to finish: 0:01:27.443765.
# validation [########################..........................] 49.63%
#         67 iterations
#    0.79061 iters/sec. Estimated time to finish: 0:01:26.009486.
# validation [#########################.........................] 50.37%
#         68 iterations
#    0.79154 iters/sec. Estimated time to finish: 0:01:24.645222.
# validation [#########################.........................] 51.11%
#         69 iterations
#    0.79486 iters/sec. Estimated time to finish: 0:01:23.033135.
# validation [#########################.........................] 51.85%
#         70 iterations
#    0.79658 iters/sec. Estimated time to finish: 0:01:21.598370.
# validation [##########################........................] 52.59%
#         71 iterations
#    0.79449 iters/sec. Estimated time to finish: 0:01:20.554833.
# validation [##########################........................] 53.33%
#         72 iterations
#     0.7948 iters/sec. Estimated time to finish: 0:01:19.265171.
# validation [###########################.......................] 54.07%
#         73 iterations
#    0.79638 iters/sec. Estimated time to finish: 0:01:17.852172.
# validation [###########################.......................] 54.81%
#         74 iterations
#    0.79772 iters/sec. Estimated time to finish: 0:01:16.467607.
# validation [###########################.......................] 55.56%
#         75 iterations
#     0.8009 iters/sec. Estimated time to finish: 0:01:14.915393.
# validation [############################......................] 56.30%
#         76 iterations
#     0.8019 iters/sec. Estimated time to finish: 0:01:13.575562.
# validation [############################......................] 57.04%
#         77 iterations
#    0.80138 iters/sec. Estimated time to finish: 0:01:12.374998.
# validation [############################......................] 57.78%
#         78 iterations
#    0.80246 iters/sec. Estimated time to finish: 0:01:11.031534.
# validation [#############################.....................] 58.52%
#         79 iterations
#    0.80204 iters/sec. Estimated time to finish: 0:01:09.822077.
# validation [#############################.....................] 59.26%
#         80 iterations
#    0.79939 iters/sec. Estimated time to finish: 0:01:08.802606.
# validation [##############################....................] 60.00%
#         81 iterations
#    0.80067 iters/sec. Estimated time to finish: 0:01:07.443165.
# validation [##############################....................] 60.74%
#         82 iterations
#     0.8014 iters/sec. Estimated time to finish: 0:01:06.134384.
# validation [##############################....................] 61.48%
#         83 iterations
#    0.80083 iters/sec. Estimated time to finish: 0:01:04.932639.
# validation [###############################...................] 62.22%
#         84 iterations
#    0.79776 iters/sec. Estimated time to finish: 0:01:03.928821.
# validation [###############################...................] 62.96%
#         85 iterations
#    0.79511 iters/sec. Estimated time to finish: 0:01:02.884321.
# validation [###############################...................] 63.70%
#         86 iterations
#    0.79625 iters/sec. Estimated time to finish: 0:01:01.538466.
# validation [################################..................] 64.44%
#         87 iterations
#    0.79709 iters/sec. Estimated time to finish: 0:01:00.219216.
# validation [################################..................] 65.19%
#         88 iterations
#    0.79386 iters/sec. Estimated time to finish: 0:00:59.204477.
# validation [################################..................] 65.93%
#         89 iterations
#    0.79436 iters/sec. Estimated time to finish: 0:00:57.908017.
# validation [#################################.................] 66.67%
#         90 iterations
#     0.7946 iters/sec. Estimated time to finish: 0:00:56.631919.
# validation [#################################.................] 67.41%
#         91 iterations
#    0.79676 iters/sec. Estimated time to finish: 0:00:55.223695.
# validation [##################################................] 68.15%
#         92 iterations
#    0.79775 iters/sec. Estimated time to finish: 0:00:53.901636.
# validation [##################################................] 68.89%
#         93 iterations
#    0.79904 iters/sec. Estimated time to finish: 0:00:52.562812.
# validation [##################################................] 69.63%
#         94 iterations
#    0.79984 iters/sec. Estimated time to finish: 0:00:51.260544.
# validation [###################################...............] 70.37%
#         95 iterations
#    0.79965 iters/sec. Estimated time to finish: 0:00:50.022178.
# validation [###################################...............] 71.11%
#         96 iterations
#     0.7984 iters/sec. Estimated time to finish: 0:00:48.847750.
# validation [###################################...............] 71.85%
#         97 iterations
#    0.79906 iters/sec. Estimated time to finish: 0:00:47.555906.
# validation [####################################..............] 72.59%
#         98 iterations
#    0.79918 iters/sec. Estimated time to finish: 0:00:46.297281.
# validation [####################################..............] 73.33%
#         99 iterations
#    0.79821 iters/sec. Estimated time to finish: 0:00:45.100929.
# validation [#####################################.............] 74.07%
#        100 iterations
#    0.80063 iters/sec. Estimated time to finish: 0:00:43.715596.
# validation [#####################################.............] 74.81%
#        101 iterations
#    0.79782 iters/sec. Estimated time to finish: 0:00:42.616360.
# validation [#####################################.............] 75.56%
#        102 iterations
#    0.79969 iters/sec. Estimated time to finish: 0:00:41.265857.
# validation [######################################............] 76.30%
#        103 iterations
#    0.80407 iters/sec. Estimated time to finish: 0:00:39.797664.
# validation [######################################............] 77.04%
#        104 iterations
#    0.80867 iters/sec. Estimated time to finish: 0:00:38.334751.
# validation [######################################............] 77.78%
#        105 iterations
#    0.81326 iters/sec. Estimated time to finish: 0:00:36.888633.
# validation [#######################################...........] 78.52%
#        106 iterations
#    0.81441 iters/sec. Estimated time to finish: 0:00:35.608639.
# validation [#######################################...........] 79.26%
#        107 iterations
#    0.81404 iters/sec. Estimated time to finish: 0:00:34.396517.
# validation [########################################..........] 80.00%
#        108 iterations
#    0.81061 iters/sec. Estimated time to finish: 0:00:33.308128.
# validation [########################################..........] 80.74%
#        109 iterations
#    0.80887 iters/sec. Estimated time to finish: 0:00:32.143415.
# validation [########################################..........] 81.48%
#        110 iterations
#    0.81032 iters/sec. Estimated time to finish: 0:00:30.851839.
# validation [#########################################.........] 82.22%
#        111 iterations
#    0.81035 iters/sec. Estimated time to finish: 0:00:29.616979.
# validation [#########################################.........] 82.96%
#        112 iterations
#    0.80905 iters/sec. Estimated time to finish: 0:00:28.428492.
# validation [#########################################.........] 83.70%
#        113 iterations
#    0.81219 iters/sec. Estimated time to finish: 0:00:27.087329.
# validation [##########################################........] 84.44%
#        114 iterations
#    0.81269 iters/sec. Estimated time to finish: 0:00:25.840239.
# validation [##########################################........] 85.19%
#        115 iterations
#    0.81381 iters/sec. Estimated time to finish: 0:00:24.575898.
# validation [##########################################........] 85.93%
#        116 iterations
#    0.81147 iters/sec. Estimated time to finish: 0:00:23.414270.
# validation [###########################################.......] 86.67%
#        117 iterations
#    0.81102 iters/sec. Estimated time to finish: 0:00:22.194392.
# validation [###########################################.......] 87.41%
#        118 iterations
#    0.81028 iters/sec. Estimated time to finish: 0:00:20.980278.
# validation [############################################......] 88.15%
#        119 iterations
#    0.80949 iters/sec. Estimated time to finish: 0:00:19.765467.
# validation [############################################......] 88.89%
#        120 iterations
#    0.81278 iters/sec. Estimated time to finish: 0:00:18.455086.
# validation [############################################......] 89.63%
#        121 iterations
#    0.80964 iters/sec. Estimated time to finish: 0:00:17.291621.
# validation [#############################################.....] 90.37%
#        122 iterations
#    0.80802 iters/sec. Estimated time to finish: 0:00:16.088749.
# validation [#############################################.....] 91.11%
#        123 iterations
#    0.80551 iters/sec. Estimated time to finish: 0:00:14.897392.
# validation [#############################################.....] 91.85%
#        124 iterations
#    0.80662 iters/sec. Estimated time to finish: 0:00:13.637233.
# validation [##############################################....] 92.59%
#        125 iterations
#    0.81362 iters/sec. Estimated time to finish: 0:00:12.290785.
# validation [##############################################....] 93.33%
#        126 iterations
#    0.81085 iters/sec. Estimated time to finish: 0:00:11.099494.
# validation [###############################################...] 94.07%
#        127 iterations
#    0.81128 iters/sec. Estimated time to finish: 0:00:09.860930.
# validation [###############################################...] 94.81%
#        128 iterations
#    0.81092 iters/sec. Estimated time to finish: 0:00:08.632180.
# validation [###############################################...] 95.56%
#        129 iterations
#    0.81223 iters/sec. Estimated time to finish: 0:00:07.387069.
# validation [################################################..] 96.30%
#        130 iterations
#    0.81337 iters/sec. Estimated time to finish: 0:00:06.147273.
# validation [################################################..] 97.04%
#        131 iterations
#    0.81289 iters/sec. Estimated time to finish: 0:00:04.920738.
# validation [################################################..] 97.78%
#        132 iterations
#     0.8077 iters/sec. Estimated time to finish: 0:00:03.714272.
# validation [#################################################.] 98.52%
#        133 iterations
#    0.80851 iters/sec. Estimated time to finish: 0:00:02.473701.
# validation [#################################################.] 99.26%
#        134 iterations
#    0.81009 iters/sec. Estimated time to finish: 0:00:01.234429.
# 24          25584       0.000654508  0.0065808   0.0116112   22148.6

# %%
import slackweb
slack = slackweb.Slack(url="https://hooks.slack.com/services/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")
slack.notify(text="おわた")

# %%
import cloudpickle
with open('model_otehon.pkl', 'wb') as f:
    cloudpickle.dump(model_res, f)

# %%
del train_loader
del val_loader
del model
del optimizer
del scheduler
del loss_func
del manager

gc.collect()

# %% [markdown]
# ## save results

# %%
import cloudpickle# %%bash
# !ls ./training_output

# %%
for f_name in ["log","loss.png", "lr.png"]:
    shutil.copy(output_dir / f_name, f_name)

# %%
log = pd.read_json("log")
best_epoch = log["val/loss"].idxmin() + 1
log.iloc[[best_epoch - 1],]

# %%
shutil.copy(output_dir / "snapshot_epoch_{}.pth".format(best_epoch), "best_model.pth")

# %%
m = get_model({
    'name': settings["model"]["name"],
    'params': {'pretrained': False, 'n_classes': 264}})
state_dict = torch.load('best_model.pth')
m.load_state_dict(state_dict)
